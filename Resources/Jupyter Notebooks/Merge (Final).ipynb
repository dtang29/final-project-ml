# %%
import numpy as np
import pandas as pd
import os

# %%
#Set the paths
registered_business_path = os.path.join('Cleaned Datasets', 'cleaned_registered_businesses.csv')
# health_scores_path = os.path.join('Cleaned Datasets', 'health_scores.csv')

#merge the aggregated health scores with MA
health_scores_path = os.path.join('Cleaned Datasets', 'aggregated_health_scores_ma.csv')


registered_business_df = pd.read_csv(registered_business_path)
health_scores_df = pd.read_csv(health_scores_path)

# %%
registered_business_df.head(10)
len(registered_business_df)
# Out:
# 223102

# %%
#lower the name of the business and street address
registered_business_df['business_name'] = registered_business_df['business_name'].str.lower()
registered_business_df['street_address'] = registered_business_df['street_address'].str.lower()

#Drop any business_name or street_address that has null values
registered_business_df['street_address'].replace('', np.nan, inplace=True)
registered_business_df = registered_business_df.dropna(subset=['street_address'])

#Convert street address column to string 
registered_business_df['street_address'] = registered_business_df['street_address'].astype('str')

#convert zipcode address column to int
#registered_business_df['zipcode'] = registered_business_df['zipcode'].astype('int')


registered_business_df.head(1)
len(registered_business_df)
# Out:
# 223098

# %%
#remove the whitespaces at the end of business and street address
registered_business_df['business_name'] = registered_business_df['business_name'].str.strip()
registered_business_df['street_address'] = registered_business_df['street_address'].str.strip()

registered_business_df.head(1)
# Out:
#                   business_name                               category  \
# 0  blossoming lotus acupuncture  Private Education and Health Services
#
#   lic_code         street_address State           City  zipcode  \
# 0      NaN  2670 leavenworth st a    CA  San Francisco  94109.0
#
#   business_start_date business_end_date neighborhoods  \
# 0          01/28/2010               NaN   North Beach
#
#                                   business_location  supervisor_district  \
# 0  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n                  2.0
#
#    Lifespan closed  age_if_opened
# 0       NaN     no         3107.0

# %%
registered_business_df.head(1)
# Out:
#                   business_name                               category  \
# 0  blossoming lotus acupuncture  Private Education and Health Services
#
#   lic_code         street_address State           City  zipcode  \
# 0      NaN  2670 leavenworth st a    CA  San Francisco  94109.0
#
#   business_start_date business_end_date neighborhoods  \
# 0          01/28/2010               NaN   North Beach
#
#                                   business_location  supervisor_district  \
# 0  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n                  2.0
#
#    Lifespan closed  age_if_opened
# 0       NaN     no         3107.0

# %%
# replace ', ", -, etc
registered_business_df['business_name'] = registered_business_df['business_name'].str.replace(r"[\"\',-.@!$%^&*]", '')

#get the first 2 words from street address
registered_business_df['formatted_address'] = registered_business_df['street_address'].str.split().str[0] + " " + registered_business_df['street_address'].str.split().str[1]
registered_business_df['formatted_name'] = registered_business_df['business_name'].str.split().str[0]

#drop the null formatted addresses 
registered_business_df = registered_business_df.dropna(subset=['formatted_address'])

#create a unique id based off the formatted address and name
registered_business_df['uniqueid'] = registered_business_df['formatted_name'] + registered_business_df['formatted_address']

#convert zipcode to integer 
#registered_business_df['zipcode'] = registered_business_df['zipcode'].astype('int')

registered_business_df.head(1)
# Out:
#                   business_name                               category  \
# 0  blossoming lotus acupuncture  Private Education and Health Services
#
#   lic_code         street_address State           City  zipcode  \
# 0      NaN  2670 leavenworth st a    CA  San Francisco  94109.0
#
#   business_start_date business_end_date neighborhoods  \
# 0          01/28/2010               NaN   North Beach
#
#                                   business_location  supervisor_district  \
# 0  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n                  2.0
#
#    Lifespan closed  age_if_opened formatted_address formatted_name  \
# 0       NaN     no         3107.0  2670 leavenworth     blossoming
#
#                      uniqueid
# 0  blossoming2670 leavenworth

# %%
#add a new column with concatted address
registered_business_df['full_address'] = registered_business_df['street_address'] + ', ' + registered_business_df['City'] + ', ' + registered_business_df['State'] + ', ' + registered_business_df['zipcode'].astype('str')
registered_business_df.head(2)
# Out:
#                   business_name                               category  \
# 0  blossoming lotus acupuncture  Private Education and Health Services
# 1  zaalouk market  deli grocery                           Retail Trade
#
#   lic_code         street_address State           City  zipcode  \
# 0      NaN  2670 leavenworth st a    CA  San Francisco  94109.0
# 1      NaN         1209 sutter st    CA  San Francisco  94109.0
#
#   business_start_date business_end_date neighborhoods  \
# 0          01/28/2010               NaN   North Beach
# 1          12/01/2015               NaN      Nob Hill
#
#                                    business_location  supervisor_district  \
# 0   2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n                  2.0
# 1  1209 SUTTER ST\nSAN FRANCISCO, CA 94109\n(37.7...                  3.0
#
#    Lifespan closed  age_if_opened formatted_address formatted_name  \
# 0       NaN     no         3107.0  2670 leavenworth     blossoming
# 1       NaN     no          974.0       1209 sutter        zaalouk
#
#                      uniqueid  \
# 0  blossoming2670 leavenworth
# 1          zaalouk1209 sutter
#
#                                         full_address
# 0  2670 leavenworth st a, San Francisco, CA, 94109.0
# 1         1209 sutter st, San Francisco, CA, 94109.0

# %% [markdown]
# # Clean up the health scores dataset

# %%
health_scores_df.head(10)
# Out:
#    business_id                              name                    address  \
# 0        95059   95059 PORTABLES SAY HEY SAUSAGE  24 WILLIE MAYS PL SEC 114
# 1         4424     BON APPETIT @ USF- OUTTA HERE            2130 FULTON ST
# 2         1674             NORDSTROM CAFE BISTRO             865 MARKET ST
# 3        37633                 100% DESSERT CAFE           2512 CLEMENT ST
# 4        65776                 111 MINNA GALLERY               111 MINNA ST
# 5        69691                1601 BAR & KITCHEN            1601 HOWARD ST
# 6        95361                       1608 BISTRO              1608 BUSH  ST
# 7         4474                 17TH & NOE MARKET              3900 17TH ST
# 8        64717                        18 REASONS              3674 18TH ST
# 9        27350            18TH STREET COMMISSARY              3334 18TH ST
#
#             city state  postal_code   latitude   longitude phone_number  \
# 0  San Francisco    CA      94107.0        NaN         NaN  14157735128
# 1  San Francisco    CA      94117.0  37.775117 -122.452065  14154225849
# 2  San Francisco    CA      94103.0  37.784317 -122.407563  14159775154
# 3  San Francisco    CA      94121.0  37.781988 -122.486252  14153097778
# 4  San Francisco    CA      94105.0  37.787378 -122.399459  14159741719
# 5  San Francisco    CA      94103.0        NaN         NaN  14153906117
# 6  San Francisco    CA      94109.0        NaN         NaN  14159227887
# 7  San Francisco    CA      94114.0  37.762638 -122.433242  14158636337
# 8  San Francisco    CA      94110.0  37.761498 -122.425402  14152419760
# 9  San Francisco    CA      94110.0  37.761965 -122.417948          NaN
#
#    score        date     type    year  month     MA   formatted_name  \
# 0  100.0  2018-03-26  routine  2018.0    3.0  100.0  95059 PORTABLES
# 1   94.0  2017-12-04  routine  2017.0   12.0   94.0      BON APPETIT
# 2   96.0  2018-01-08  routine  2018.0    1.0   93.0   NORDSTROM CAFE
# 3   88.0  2018-06-22  routine  2018.0    6.0   85.0     100% DESSERT
# 4  100.0  2018-05-01  routine  2018.0    5.0   96.0        111 MINNA
# 5   90.0  2018-05-31  routine  2018.0    5.0   84.0         1601 BAR
# 6   79.0  2018-05-18  routine  2018.0    5.0   79.0      1608 BISTRO
# 7   96.0  2017-10-11  routine  2017.0   10.0   96.0           17TH &
# 8   92.0  2018-02-28  routine  2018.0    2.0   95.0       18 REASONS
# 9   85.0  2018-06-20  routine  2018.0    6.0   84.0      18TH STREET
#
#   formatted_address
# 0         24 WILLIE
# 1       2130 FULTON
# 2        865 MARKET
# 3      2512 CLEMENT
# 4         111 MINNA
# 5       1601 HOWARD
# 6         1608 BUSH
# 7         3900 17TH
# 8         3674 18TH
# 9         3334 18TH

# %%
#lower the name of the business and street address
health_scores_df['name'] = health_scores_df['name'].str.lower()
health_scores_df['address'] = health_scores_df['address'].str.lower()

#Drop any street_address that has null values
health_scores_df['address'].replace('', np.nan, inplace=True)
health_scores_df = health_scores_df.dropna(subset=['address'])

#Convert street address column to string 
health_scores_df['address'] = health_scores_df['address'].astype(str)

registered_business_df.head(1)
len(registered_business_df)
# Out:
# 223033

# %%
#remove the whitespaces at the end of business and street address
health_scores_df['name'] = health_scores_df['name'].str.strip()
health_scores_df['address'] = health_scores_df['address'].str.strip()

health_scores_df.head(1)
# Out:
#    business_id                             name                    address  \
# 0        95059  95059 portables say hey sausage  24 willie mays pl sec 114
#
#             city state  postal_code  latitude  longitude phone_number  score  \
# 0  San Francisco    CA      94107.0       NaN        NaN  14157735128  100.0
#
#          date     type    year  month     MA   formatted_name  \
# 0  2018-03-26  routine  2018.0    3.0  100.0  95059 PORTABLES
#
#   formatted_address
# 0         24 WILLIE

# %%
# replace ', ", -, etc
health_scores_df['name'] = health_scores_df['name'].str.replace(r"[\"\',-.@!$%^&*]", '')

#get the first 2 words from street address
health_scores_df['formatted_address'] = health_scores_df['address'].str.split().str[0] + " " + health_scores_df['address'].str.split().str[1]
health_scores_df['formatted_name'] = health_scores_df['name'].str.split().str[0]

#drop the null formatted addresses 
health_scores_df = health_scores_df.dropna(subset=['formatted_address'])

#create a unique id based off the formatted address and name
health_scores_df['uniqueid'] = health_scores_df['formatted_name'] + health_scores_df['formatted_address']

# %%
#get the columns we need
# health_scores_df = health_scores_df[['business_id', 'name', 'score', 'year', 'formatted_address', 'formatted_name', 'latitude', 'longitude', 'uniqueid']]

#moving average
health_scores_df = health_scores_df[['business_id', 'name', 'MA', 'year', 'formatted_address', 'formatted_name', 'latitude', 'longitude', 'uniqueid']]

len(health_scores_df)

# health_scores_df.head(1000)
# Out:
# 5055

# %%
#Merge the registered business df with the geocodes to get unique location id
merged = registered_business_df.merge(health_scores_df, on='uniqueid')

merged = merged[merged['category'] == 'Food Services']
len(merged)
# Out:
# 3432

# %%
merged.head(100)
# Out:
#                                          business_name       category  \
# 0                                    yokai express inc  Food Services
# 1                                    sizzling pot king  Food Services
# 2                          burma super star restaurant  Food Services
# 5                                      foundation cafe  Food Services
# 7                               new york pizza kitchen  Food Services
# 8                               new york pizza kitchen  Food Services
# 9                             corner bakery cafe #1584  Food Services
# 10                             corner bakery cafe #106  Food Services
# 11                             corner bakery cafe #106  Food Services
# 12                                   sorrel restaurant  Food Services
# 13                                     braised + bread  Food Services
# 14                               joint venture kitchen  Food Services
# 15                          there sushibar  restaurant  Food Services
# 18                               native baking company  Food Services
# 23                                            the melt  Food Services
# 28                                   the dosa brothers  Food Services
# 33                               alcatraz landing cafe  Food Services
# 34                                    tenroku ramen #2  Food Services
# 52                           yan yan seafood resaurant  Food Services
# 53                             the grilledcheezguy llc  Food Services
# 54                                         simply cafe  Food Services
# 55                                        orchids cafe  Food Services
# 56                                 the sausage factory  Food Services
# 57                                 the sausage factory  Food Services
# 58                                            mr bread  Food Services
# 59                                            mr bread  Food Services
# 60                            babys eatery and palabok  Food Services
# 61                               babys eatery  palabok  Food Services
# 65                                        tommys joynt  Food Services
# 67                                           jacks bar  Food Services
# ..                                                 ...            ...
# 201                                       happy donuts  Food Services
# 202                             creperie saint germain  Food Services
# 203                              creperie saintgermain  Food Services
# 204                                 casa de la condesa  Food Services
# 205                      casa de la condesa restaurant  Food Services
# 207                                hotel san francisco  Food Services
# 208                          memphis minnies bbq joint  Food Services
# 209                          memphis minnies bbq joint  Food Services
# 210                          memphis minnies bbq joint  Food Services
# 211                             kentucky fried chicken  Food Services
# 212                         toyama japanese restaurant  Food Services
# 213                                    gourmet kitchen  Food Services
# 220                                        z zoul cafe  Food Services
# 222                                     casa lucas mkt  Food Services
# 223                                      fullskoop inc  Food Services
# 224                                      fullskoop inc  Food Services
# 237  505 pinterest dining garage level kitchen and ...  Food Services
# 238  505 pinterest dining garage level kitchen and ...  Food Services
# 239                               505 pinterest retail  Food Services
# 240                               505 pinterest retail  Food Services
# 241                      slice house by tony gemignani  Food Services
# 242                                           papis sf  Food Services
# 243                                           papis sf  Food Services
# 250                                        t bear cafe  Food Services
# 252                                    wing lee bakery  Food Services
# 254                                    wing lee bakery  Food Services
# 255                                  smitten ice cream  Food Services
# 257                                  smitten ice cream  Food Services
# 258                                         beer nerds  Food Services
# 283                        bon appetit  usf crossroads  Food Services
#
#                                           lic_code  \
# 0                                              NaN
# 1                    Restaurant 1,000 - 2,000 Sqft
# 2                    Restaurant 1,000 - 2,000 Sqft
# 5                                              NaN
# 7                                              NaN
# 8                  Restaurant Less Than 1,000 Sqft
# 9    Places Of Public Assembly & Open-Air Assembly
# 10                                             NaN
# 11                                             NaN
# 12                                        Multiple
# 13                   Restaurant 1,000 - 2,000 Sqft
# 14                   Restaurant 1,000 - 2,000 Sqft
# 15              Restaurant Greater Than 2,000 Sqft
# 18                                         Caterer
# 23                   Restaurant 1,000 - 2,000 Sqft
# 28                                        Multiple
# 33              Restaurant Greater Than 2,000 Sqft
# 34                   Restaurant 1,000 - 2,000 Sqft
# 52              Restaurant Greater Than 2,000 Sqft
# 53                                             NaN
# 54                   Restaurant 1,000 - 2,000 Sqft
# 55                   Restaurant 1,000 - 2,000 Sqft
# 56                                             NaN
# 57                   Restaurant 1,000 - 2,000 Sqft
# 58                 Restaurant Less Than 1,000 Sqft
# 59                                             NaN
# 60                                             NaN
# 61                                             NaN
# 65                                        Multiple
# 67   Places Of Public Assembly & Open-Air Assembly
# ..                                             ...
# 201                                       Multiple
# 202                              Catering Facility
# 203                                            NaN
# 204                                            NaN
# 205                  Restaurant 1,000 - 2,000 Sqft
# 207                                       Multiple
# 208                                            NaN
# 209                                            NaN
# 210                  Restaurant 1,000 - 2,000 Sqft
# 211                                       Multiple
# 212                  Restaurant 1,000 - 2,000 Sqft
# 213                         Take-Out Establishment
# 220                  Restaurant 1,000 - 2,000 Sqft
# 222   Retail Food Market W/food Prep. Lt 5001 Sqft
# 223                         Mobile Food Facility 4
# 224                         Mobile Food Facility 4
# 237                Employee Cafeterias W/food Prep
# 238                Employee Cafeterias W/food Prep
# 239                  Restaurant 1,000 - 2,000 Sqft
# 240                  Restaurant 1,000 - 2,000 Sqft
# 241                                            NaN
# 242                Restaurant Less Than 1,000 Sqft
# 243                                            NaN
# 250                Restaurant Less Than 1,000 Sqft
# 252                  Restaurant 1,000 - 2,000 Sqft
# 254                  Restaurant 1,000 - 2,000 Sqft
# 255                                       Multiple
# 257                                            NaN
# 258                  Restaurant 1,000 - 2,000 Sqft
# 283             Retail Mkts W/o Prep (Under 5,001)
#
#                  street_address State           City  zipcode  \
# 0           135 4th st ste 4000    CA  San Francisco  94103.0
# 1                    139 8th st    CA  San Francisco  94103.0
# 2                309 clement st    CA  San Francisco  94118.0
# 5                    645 5th st    CA  San Francisco  94107.0
# 7                   127 eddy st    CA  San Francisco  94102.0
# 8                   127 eddy st    CA  San Francisco  94102.0
# 9                 665 market st    CA  San Francisco  94105.0
# 10                665 market st    CA  San Francisco  94105.0
# 11                665 market st    CA  San Francisco  94105.0
# 12           3228 sacramento st    CA  San Francisco  94115.0
# 13          50 post st unit 65a    CA  San Francisco  94104.0
# 14              167 11th street    CA  San Francisco  94103.0
# 15                   393 bay st    CA  San Francisco  94133.0
# 18        1324 fitzgerald ave c    CA  San Francisco  94124.0
# 23         1 embarcadero center    CA  San Francisco  94111.0
# 28            1 embarcadero ctr    CA  San Francisco  94111.0
# 33          pier 33 embarcadero    CA  San Francisco  94111.0
# 34              4435 mission st    CA  San Francisco  94112.0
# 52                2241 judah st    CA  San Francisco  94122.0
# 53    529 stevenson st unit 100    CA  San Francisco  94103.0
# 54                 340 grove st    CA  San Francisco  94102.0
# 55               1031 ocean ave    CA  San Francisco  94112.0
# 56                517 castro st    CA  San Francisco  94114.0
# 57                517 castro st    CA  San Francisco  94114.0
# 58              1018 taraval st    CA  San Francisco  94116.0
# 59              1018 taraval st    CA  San Francisco  94116.0
# 60          4609 mission street    CA  San Francisco  94112.0
# 61              4609 mission st    CA  San Francisco  94112.0
# 202          10/01/2016               NaN                             NaN
# 203          03/01/2018               NaN                             NaN
# 204          01/31/2018               NaN                         Mission
# 205          01/31/2018               NaN                         Mission
# 207          09/28/2017               NaN                       Chinatown
# 208          05/01/2018               NaN                    Hayes Valley
# 209          05/01/2018               NaN                    Hayes Valley
# 210          05/16/2006        05/01/2018                             NaN
# 211          10/01/1968               NaN                      Tenderloin
# 212          02/05/2018               NaN                             NaN
# 213          02/01/2000               NaN                       Chinatown
# 220          02/01/2018               NaN                             NaN
# 222          01/01/1992               NaN                             NaN
# 223          06/06/2017               NaN                             NaN
# 224          06/06/2017               NaN                             NaN
# 237          10/01/1968               NaN                 South of Market
# 238          10/01/1968               NaN                 South of Market
# 239          10/01/1968               NaN                             NaN
# 240          10/01/1968               NaN                             NaN
# 241          02/10/2009               NaN                             NaN
# 242          12/11/2017               NaN                             NaN
# 243          12/11/2017               NaN                             NaN
# 250          02/06/2018               NaN                             NaN
# 252          02/08/2018               NaN                             NaN
# 254          12/01/2013        02/21/2018                  Inner Richmond
# 255          01/01/2015               NaN                             NaN
# 257          01/01/2015               NaN                             NaN
# 258          02/09/2018               NaN                             NaN
# 283          07/01/1987               NaN                             NaN
#
#         ...                   uniqueid  \
# 0       ...               yokai135 4th
# 1       ...            sizzling139 8th
# 2       ...           burma309 clement
# 5       ...          foundation645 5th
# 7       ...                new127 eddy
# 8       ...                new127 eddy
# 9       ...           corner665 market
# 10      ...           corner665 market
# 11      ...           corner665 market
# 12      ...      sorrel3228 sacramento
# 13      ...             braised50 post
# 14      ...              joint167 11th
# 15      ...               there393 bay
# 18      ...      native1324 fitzgerald
# 23      ...           the1 embarcadero
# 28      ...           the1 embarcadero
# 33      ...            alcatrazpier 33
# 34      ...        tenroku4435 mission
# 52      ...              yan2241 judah
# 53      ...           the529 stevenson
# 54      ...            simply340 grove
# 55      ...          orchids1031 ocean
# 56      ...              the517 castro
# 57      ...              the517 castro
# 58      ...             mr1018 taraval
# 59      ...             mr1018 taraval
# 60      ...          babys4609 mission
# 61      ...          babys4609 mission
# 65      ...           tommys1101 geary
# 67      ...      jacks2801 leavenworth
# ..      ...                        ...
# 201     ...             happy3801 24th
# 202     ...         creperie1750 cesar
# 203     ...         creperie1750 cesar
# 204     ...           casa2763 mission
# 205     ...           casa2763 mission
# 207     ...        hotel653 commercial
# 208     ...          memphis576 haight
# 209     ...          memphis576 haight
# 210     ...          memphis576 haight
# 211     ...           kentucky691 eddy
# 212     ...           toyama3727 geary
# 213     ...       gourmet1051 stockton
# 220     ...                  z295 eddy
# 222     ...              casa2934 24th
# 223     ...            fullskoop1 bush
# 224     ...            fullskoop1 bush
# 237     ...             505505 brannan
# 238     ...             505505 brannan
# 239     ...             505505 brannan
# 240     ...             505505 brannan
# 241     ...         slice1556 stockton
# 242     ...             papis846 geary
# 243     ...             papis846 geary
# 250     ...                 t57 walter
# 252     ...            wing503 clement
# 254     ...            wing503 clement
# 255     ...         smitten432 octavia
# 257     ...         smitten432 octavia
# 258     ...              beer3331 24th
# 283     ...             bon2130 fulton
# 252                                    wing lee bakery   83.0  2018.0
# 254                                    wing lee bakery   83.0  2018.0
# 255                                  smitten ice cream   99.0  2018.0
# 257                                  smitten ice cream   99.0  2018.0
# 258                                         beer nerds   94.0  2018.0
# 283                        bon appetit  usf outta here   94.0  2017.0
#
#     formatted_address_y formatted_name_y   latitude   longitude
# 0               135 4th            yokai        NaN         NaN
# 1               139 8th         sizzling        NaN         NaN
# 2           309 clement            burma  37.783004 -122.462539
# 5               645 5th       foundation        NaN         NaN
# 7              127 eddy              new        NaN         NaN
# 8              127 eddy              new        NaN         NaN
# 9            665 market           corner        NaN         NaN
# 10           665 market           corner        NaN         NaN
# 11           665 market           corner        NaN         NaN
# 12      3228 sacramento           sorrel        NaN         NaN
# 13              50 post          braised        NaN         NaN
# 14             167 11th            joint        NaN         NaN
# 15              393 bay            there        NaN         NaN
# 18      1324 fitzgerald           native        NaN         NaN
# 23        1 embarcadero              the  37.794588 -122.399642
# 28        1 embarcadero              the  37.794588 -122.399642
# 33              pier 33         alcatraz        NaN         NaN
# 34         4435 mission          tenroku  37.727239 -122.432799
# 52           2241 judah              yan        NaN         NaN
# 53        529 stevenson              the        NaN         NaN
# 54            340 grove           simply        NaN         NaN
# 55           1031 ocean          orchids        NaN         NaN
# 56           517 castro              the        NaN         NaN
# 57           517 castro              the        NaN         NaN
# 58         1018 taraval               mr        NaN         NaN
# 59         1018 taraval               mr        NaN         NaN
# 60         4609 mission            babys  37.724579 -122.434879
# 61         4609 mission            babys  37.724579 -122.434879
# 65           1101 geary           tommys        NaN         NaN
# 67     2801 leavenworth            jacks  37.807155 -122.419004
# ..                  ...              ...        ...         ...
# 201           3801 24th            happy        NaN         NaN
# 202          1750 cesar         creperie        NaN         NaN
# 203          1750 cesar         creperie        NaN         NaN
# 204        2763 mission             casa        NaN         NaN
# 205        2763 mission             casa        NaN         NaN
# 207      653 commercial            hotel        NaN         NaN
# 208          576 haight          memphis  37.771978 -122.431654
# 209          576 haight          memphis  37.771978 -122.431654
# 210          576 haight          memphis  37.771978 -122.431654
# 211            691 eddy         kentucky  37.783053 -122.418988
# 212          3727 geary           toyama        NaN         NaN
# 213       1051 stockton          gourmet  37.795594 -122.408204
# 220            295 eddy                z        NaN         NaN
# 222           2934 24th             casa        NaN         NaN
# 223              1 bush        fullskoop        NaN         NaN
# 224              1 bush        fullskoop        NaN         NaN
# 237         505 brannan              505        NaN         NaN
# 238         505 brannan              505        NaN         NaN
# 239         505 brannan              505        NaN         NaN
# 240         505 brannan              505        NaN         NaN
# 241       1556 stockton            slice  37.800218 -122.409096
# 242           846 geary            papis        NaN         NaN
# 243           846 geary            papis        NaN         NaN
# 250           57 walter                t        NaN         NaN
# 252         503 clement             wing        NaN         NaN
# 254         503 clement             wing        NaN         NaN
# 255         432 octavia          smitten        NaN         NaN
# 257         432 octavia          smitten        NaN         NaN
# 258           3331 24th             beer        NaN         NaN
# 283         2130 fulton              bon  37.775117 -122.452065
#
# [100 rows x 27 columns]

# %%
path = os.path.join('Cleaned Datasets', 'final-merged.csv')
merged.to_csv(path, index=False)
