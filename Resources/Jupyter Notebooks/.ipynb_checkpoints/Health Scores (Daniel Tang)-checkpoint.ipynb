# %%
#dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
#Set path
businesses_path = os.path.join('..','Raw', 'businesses.csv')
inspections_path = os.path.join('..','Raw', 'inspections.csv')
legend_path = os.path.join('..','Raw', 'legend.csv')
violations_path = os.path.join('..','Raw', 'violations.csv')

#Read in csv file as dataframe
businesses_df = pd.read_csv(businesses_path, encoding='latin-1')
inspections_df = pd.read_csv(inspections_path)
legend_df = pd.read_csv(legend_path)
violations_df = pd.read_csv(violations_path)

#List of columns
#registered_business_df.columns.values

# %%
businesses_df.head(5)
# Out:
#    business_id                                name  \
# 0           19               NRGIZE LIFESTYLE CAFE
# 1           24  OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 2           31      NORMAN'S ICE CREAM AND FREEZES
# 3           45                 CHARLIE'S DELI CAFE
# 4           48                          ART'S CAFE
#
#                          address           city state postal_code   latitude  \
# 0   1200 VAN NESS AVE, 3RD FLOOR  San Francisco    CA       94109  37.786848
# 1  500 CALIFORNIA ST, 2ND  FLOOR  San Francisco    CA       94104  37.792888
# 2           2801 LEAVENWORTH ST   San Francisco    CA       94133  37.807155
# 3                3202 FOLSOM ST   San Francisco    CA       94110  37.747114
# 4                 747 IRVING ST   San Francisco    CA       94122  37.764013
#
#     longitude phone_number
# 0 -122.421547  14157763262
# 1 -122.403135  14156779494
# 2 -122.419004          NaN
# 3 -122.413641  14156415051
# 4 -122.465749  14156657440

# %%
inspections_df.head(5)

#Cast the dat as a string and then convert it to a datetime object
inspections_df['date'] = pd.to_datetime(inspections_df['date'].astype(str), format='%Y%m%d')

#Add a column extracting the year
inspections_df['year'] = inspections_df['date'].dt.year

#Add a column extracting the month
inspections_df['month'] = inspections_df['date'].dt.month
# Out:
#    business_id  score      date     type
# 0           19     94  20171211  routine
# 1           19     96  20180607  routine
# 2           19     94  20160513  routine
# 3           24     96  20160311  routine
# 4           24     98  20161005  routine

# %%
# df = inspections_df.groupby(['year', 'business_id'])['score'].mean()
# df = df.reset_index()
# inspections_df = df.sort_values(by=['business_id','year'], ascending=True).reset_index(drop=True)
# inspections_df

# %%
legend_df.head(5)
# Out:
#    Minimum_Score  Maximum_Score        Description
# 0              0             70               Poor
# 1             71             85  Needs Improvement
# 2             86             90           Adequate
# 3             91            100               Good

# %%
violations_df
# Out:
#        business_id      date  \
# 0               19  20180607
# 1               19  20171211
# 2               19  20171211
# 3               19  20160513
# 4               19  20160513
# 5               19  20160513
# 6               24  20171101
# 7               24  20160311
# 8               24  20160311
# 9               31  20180615
# 10              31  20180615
# 11              31  20151204
# 12              45  20180529
# 13              45  20180529
# 14              45  20180529
# 15              45  20180529
# 16              45  20180529
# 17              45  20170914
# 18              45  20170914
# 19              45  20170914
# 20              45  20170914
# 21              45  20170307
# 22              45  20170307
# 23              45  20170307
# 24              45  20170307
# 25              45  20170307
# 26              45  20160614
# 27              45  20160614
# 28              45  20160614
# 29              45  20160614
# ...            ...       ...
# 39829        96110  20180614
# 39830        96110  20180614
# 39831        96147  20180503
# 39832        96147  20180503
# 39833        96147  20180503
# 39834        96147  20180503
# 39835        96147  20180503
# 39836        96147  20180503
# 39837        96147  20180503
# 39838        96147  20180503
# 39839        96147  20180503
# 39840        96268  20180713
# 39841        96268  20180713
# 39842        96270  20180418
# 39843        96270  20180418
# 39844        96270  20180418
# 39845        96270  20180418
# 39846        96270  20180418
# 39847        96270  20180418
# 39848        96270  20180418
# 39849        96537  20180629
# 39850        96537  20180629
# 39851        96577  20180713
# 39852        96577  20180713
# 39853        96577  20180713
# 39854        96591  20180723
# 39855        96591  20180723
# 39856        96591  20180723
# 39857        96775  20180710
# 39858        96775  20180710
#
#                                              description
# 0      Inadequate food safety knowledge or lack of ce...
# 1      Unapproved or unmaintained equipment or utensi...
# 2      Inadequate food safety knowledge or lack of ce...
# 3      Food safety certificate or food handler card n...
# 4      Unapproved or unmaintained equipment or utensi...
# 5      Unclean or degraded floors walls or ceilings  ...
# 6                                  Improper food storage
# 7      Unclean or degraded floors walls or ceilings  ...
# 8           Unclean or degraded floors walls or ceilings
# 9       Improper storage of equipment utensils or linens
# 10     Wiping cloths not clean or properly stored or ...
# 11     Food safety certificate or food handler card n...
# 12                      Moderate risk vermin infestation
# 13     Wiping cloths not clean or properly stored or ...
# 14                      Unclean nonfood contact surfaces
# 15                    Inadequate ventilation or lighting
# 16          Unclean or degraded floors walls or ceilings
# 17     Moderate risk food holding temperature   [ dat...
# 18     High risk vermin infestation  [ date violation...
# 19     Unclean or degraded floors walls or ceilings  ...
# 20     Unclean nonfood contact surfaces  [ date viola...
# 21     Food safety certificate or food handler card n...
# 22     Unclean nonfood contact surfaces  [ date viola...
# 23     Moderate risk vermin infestation  [ date viola...
# 24     Wiping cloths not clean or properly stored or ...
# 25     Unclean or degraded floors walls or ceilings  ...
# 26     Unapproved or unmaintained equipment or utensi...
# 27     Moderate risk vermin infestation  [ date viola...
# 28     Unclean or degraded floors walls or ceilings  ...
# 29     Foods not protected from contamination  [ date...
# ...                                                  ...
# 39829  Other low risk violation  [ date violation cor...
# 39830  Moderate risk food holding temperature   [ dat...
# 39831  Inadequate food safety knowledge or lack of ce...
# 39832       Unclean or degraded floors walls or ceilings
# 39833                          Unpermitted food facility
# 39834         Unsanitary employee garments hair or nails
# 39835  Inadequate and inaccessible handwashing facili...
# 39836            Moderate risk food holding temperature
# 39837   Unapproved or unmaintained equipment or utensils
# 39838  Wiping cloths not clean or properly stored or ...
# 39839  Employee eating or smoking  [ date violation c...
# 39840                     Improper or defective plumbing
# 39841  Inadequate and inaccessible handwashing facili...
# 39842  Unsanitary employee garments hair or nails  [ ...
# 39843  Unclean unmaintained or improperly constructed...
# 39844  Unapproved or unmaintained equipment or utensi...
# 39845  High risk food holding temperature   [ date vi...
# 39846  Inadequate and inaccessible handwashing facili...
# 39847  Unclean or degraded floors walls or ceilings  ...
# 39848  Improper storage use or identification of toxi...
# 39849  Food safety certificate or food handler card n...
# 39850       Unclean or degraded floors walls or ceilings
# 39851            Moderate risk food holding temperature
# 39852   Unapproved or unmaintained equipment or utensils
# 39853       Unclean or degraded floors walls or ceilings
# 39854                          Improper thawing methods
# 39855  Unclean or unsanitary food contact surfaces  [...
# 39856                           Improper cooling methods
# 39857            Moderate risk food holding temperature
# 39858  Wiping cloths not clean or properly stored or ...
#
# [39859 rows x 3 columns]

# %%
# #Cast the date as a string and then convert it to a datetime object
# violations_df['date'] = pd.to_datetime(violations_df['date'].astype(str), format='%Y%m%d')

# #Add a column extracting the year
# violations_df['year'] = violations_df['date'].dt.year

# #Add a column extracting the month
# violations_df['month'] = violations_df['date'].dt.month

# #Group by the year and business id
# df1 = violations_df.groupby(['year', 'business_id'])['score'].mean()
# df1 = df1.reset_index()

# violations_df = df1.sort_values(by=['business_id','year'], ascending=True).reset_index(drop=True)
# violations_df.head(5)

# %%
#merge the files with left join
final_df = businesses_df.merge(inspections_df, left_on='business_id', right_on='business_id', how='left')
#final_df = final_df.merge(violations_df, left_on=['business_id','date'], right_on=['business_id','date'], how='left')
final_df
# Out:
#        business_id                                  name  \
# 0               19                 NRGIZE LIFESTYLE CAFE
# 1               19                 NRGIZE LIFESTYLE CAFE
# 2               19                 NRGIZE LIFESTYLE CAFE
# 3               24    OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 4               24    OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 5               24    OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 6               31        NORMAN'S ICE CREAM AND FREEZES
# 7               31        NORMAN'S ICE CREAM AND FREEZES
# 8               45                   CHARLIE'S DELI CAFE
# 9               45                   CHARLIE'S DELI CAFE
# 10              45                   CHARLIE'S DELI CAFE
# 11              45                   CHARLIE'S DELI CAFE
# 12              45                   CHARLIE'S DELI CAFE
# 13              48                            ART'S CAFE
# 14              48                            ART'S CAFE
# 15              54                   RHODA GOLDMAN PLAZA
# 16              54                   RHODA GOLDMAN PLAZA
# 17              56                            CAFE X + O
# 18              56                            CAFE X + O
# 19              56                            CAFE X + O
# 20              56                            CAFE X + O
# 21              58                           OASIS GRILL
# 22              58                           OASIS GRILL
# 23              61                              CHOWDERS
# 24              61                              CHOWDERS
# 25              61                              CHOWDERS
# 26              61                              CHOWDERS
# 27              66                      STARBUCKS COFFEE
# 28              66                      STARBUCKS COFFEE
# 29              66                      STARBUCKS COFFEE
# ...            ...                                   ...
# 14839        96592         JASPER'S CORNER TAP & KITCHEN
# 14840        96599             MAI MAI SANDWICH & BAKERY
# 14841        96608                           EKO KITCHEN
# 14842        96643                 CUPS AND CAKES BAKERY
# 14843        96654                MAMA COCO'S RESTUARANT
# 14844        96670                                   903
# 14845        96671                               EL CAFE
# 14846        96692                  LAGUNA GARDEN BAKERY
# 14847        96698                               EIGHTEA
# 14848        96718                      PALACE OF SPICES
# 14849        96719                     CAPTAIN KONA CAFE
# 14850        96721                   SNOW GARDEN EXPRESS
# 14851        96723                   STONESTOWN GALLERIA
# 14852        96774           DANIEL SCOTT RIPLEY CATERER
# 14853        96775                      WOW THAI KITCHEN
# 14854        96776                    MAYA RICO BY LUCHO
# 14855        96779  SORABOL KOREAN BBQ AND ASIAN NOODLES
# 14856        96784                PRESIDIO PIZZA COMPANY
# 14857        96793                      NEW TIKKA MASALA
# 14858        96795                            KEBAB KING
# 14859        96815                        ON DOG DOG LLC
# 14860        96912                               LOVESSY
# 14861        96913                       MENDOCINO FARMS
# 14862        96914                                  HART
# 14863        96936                HARDWOOD BAR & SMOKERY
# 14864        96938                            POKE REESE
# 14865        97096                        VOLCANO KIMCHI
# 14849        NaN         NaN  14157849590    NaN         NaN      NaN
# 14850        NaN         NaN  14153007071    NaN         NaN      NaN
# 14851        NaN         NaN          NaN  100.0  20180711.0  routine
# 14852        NaN         NaN  14152152714    NaN         NaN      NaN
# 14853        NaN         NaN  14155836726   94.0  20180710.0  routine
# 14854        NaN         NaN  14153361253    NaN         NaN      NaN
# 14855        NaN         NaN  14155906750    NaN         NaN      NaN
# 14856        NaN         NaN  14153518787    NaN         NaN      NaN
# 14857        NaN         NaN  14159443220    NaN         NaN      NaN
# 14858        NaN         NaN  14153280290    NaN         NaN      NaN
# 14859        NaN         NaN  14153122707    NaN         NaN      NaN
# 14860        NaN         NaN  14158237573    NaN         NaN      NaN
# 14861        NaN         NaN  14155880511    NaN         NaN      NaN
# 14862        NaN         NaN  14154256513    NaN         NaN      NaN
# 14863        NaN         NaN  14152719880    NaN         NaN      NaN
# 14864        NaN         NaN  14154633411    NaN         NaN      NaN
# 14865        NaN         NaN  14155826692    NaN         NaN      NaN
# 14866        NaN         NaN  14158261988    NaN         NaN      NaN
# 14867        NaN         NaN  14155166999    NaN         NaN      NaN
# 14868        NaN         NaN  14159143365    NaN         NaN      NaN
#
# [14869 rows x 12 columns]

# %%
#Cast the dat as a string and then convert it to a datetime object
final_df['date'] = pd.to_datetime(final_df['date'].astype(str), format='%Y%m%d')

#Add a column extracting the year
final_df['year'] = final_df['date'].dt.year

#Add a column extracting the month
final_df['month'] = final_df['date'].dt.month
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-8429f601f5bd> in <module>()
#       1 #Cast the dat as a string and then convert it to a datetime object
# ----> 2 final_df['date'] = pd.to_datetime(final_df['date'].astype(str), format='%Y%m%d')
#       3
#       4 #Add a column extracting the year
#       5 final_df['year'] = final_df['date'].dt.year
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     371     elif isinstance(arg, ABCSeries):
#     372         from pandas import Series
# --> 373         values = _convert_listlike(arg._values, True, format)
#     374         result = Series(values, index=arg.index, name=arg.name)
#     375     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     305             except (ValueError, TypeError):
# --> 306                 raise e
#     307
#     308     if arg is None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     271                     try:
#     272                         result = array_strptime(arg, format, exact=exact,
# --> 273                                                 errors=errors)
#     274                     except tslib.OutOfBoundsDatetime:
#     275                         if errors == 'raise':
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2017-12-11' does not match format '%Y%m%d' (match)

# %%
final_df = final_df.reset_index(drop=True)
final_df
# Out:
#        business_id                                  name  \
# 0               19                 NRGIZE LIFESTYLE CAFE
# 1               19                 NRGIZE LIFESTYLE CAFE
# 2               19                 NRGIZE LIFESTYLE CAFE
# 3               24    OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 4               24    OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 5               24    OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 6               31        NORMAN'S ICE CREAM AND FREEZES
# 7               31        NORMAN'S ICE CREAM AND FREEZES
# 8               45                   CHARLIE'S DELI CAFE
# 9               45                   CHARLIE'S DELI CAFE
# 10              45                   CHARLIE'S DELI CAFE
# 11              45                   CHARLIE'S DELI CAFE
