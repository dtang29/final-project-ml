# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df_csv = pd.read_csv('cleanDatasets/master_dataset.csv')
df = pd.DataFrame(df_csv)
print("Number of records: " + str(len(df)))
# df.columns.values
# df.lic_code.unique()
# Out:
# Number of records: 2232

# %%
# Filter

df = df[df['Opening_year'] >= 2010] # Only restaurants opened after 2010.

dfN = df[df['lic_code'].isnull() == True] # Identify locations with null lic_code
dfN['business_name'].unique() # Observe location by name, make determination about what to drop

# Dropping restaurant locations that are part of hotels, schools, have incomplete names
df = df.drop(df[df.business_name.isin(["sf hilton banquet facility","san francisco proper hotel  villon",
                                      'j  e restaurant', 'epicurean at mercy high school'
                                      ])].index)

# We want restaurants, not locations specialized in beverages
df = df[df.business_name.str.contains("cafe") == False]
df = df[df.business_name.str.contains("coffee") == False]
df = df[df.business_name.str.contains("tea") == False]
df = df[df.business_name.str.contains("juice") == False]
df = df[df.business_name.str.contains("boba") == False]

# Might as well remove the handful of bars/taverns that serve food (only 3)
df = df.drop(df[df.lic_code.isin(["Bars/taverns W/food Prep"])].index)

# Add Rating and Price info from the Google Places API.
g_csv = pd.read_csv('places_price_ratings.csv')
g = pd.DataFrame(g_csv)

g = g.drop(['input_string','Unnamed: 0','latitude','longitude','name','number_of_results','status'],
                        axis=1)

df = df.join(g, lsuffix='full_address', rsuffix='formatted_address')

df = df.drop(['formatted_address'],
                        axis=1)
print(len(df))
df.head()
# Out:
# 983
#             business_name                       lic_code       street_address  \
# 0       yokai express inc                            NaN  135 4th st ste 4000
# 1       sizzling pot king  Restaurant 1,000 - 2,000 Sqft           139 8th st
# 4  new york pizza kitchen                            NaN          127 eddy st
# 5         braised + bread  Restaurant 1,000 - 2,000 Sqft  50 post st unit 65a
# 6   joint venture kitchen  Restaurant 1,000 - 2,000 Sqft      167 11th street
#
#   business_start_date business_end_date  Lifespan isClosed  \
# 0          2017-12-28               NaN     221.0       no
# 1          2017-12-28               NaN     221.0       no
# 4          2016-03-16        2017-03-14     363.0      yes
# 5          2018-01-02               NaN     216.0       no
# 6          2017-06-26               NaN     406.0       no
#
#                                     full_address  business_id  \
# 0  135 4th st ste 4000, San Francisco, CA, 94103        94310
# 1           139 8th st, San Francisco, CA, 94103        94408
# 4          127 eddy st, San Francisco, CA, 94102        91028
# 5  50 post st unit 65a, San Francisco, CA, 94104        94432
# 6      167 11th street, San Francisco, CA, 94103        92980
#
#                      name   ...   HD02_S171  HD02_S180  HD02_S181  HD02_S184  \
# 0           yokai express   ...        17.8      100.0       37.2       62.8
# 1       sizzling pot king   ...        18.4      100.0        9.4       90.6
# 4  new york pizza kitchen   ...        12.4      100.0        2.5       97.5
# 5         braised + bread   ...        28.5      100.0        8.6       91.4
# 6   joint venture kitchen   ...        18.4      100.0        9.4       90.6
#
#    Opening_year Closing_year  Opening_month Closing_month  price_level  rating
# 0          2017          NaN             12           NaN          NaN     4.0
# 1          2017          NaN             12           NaN          2.0     4.3
# 4          2016       2017.0              3           3.0          1.0     3.8
# 5          2018          NaN              1           NaN          NaN     NaN
# 6          2017          NaN              6           NaN          3.0     4.7
#
# [5 rows x 111 columns]

# %%
df.to_csv("cleanDatasets/master_dataset2010.csv",index=False)

# Dropped rows with Nulls for ratings and price
df = df.dropna(subset=['price_level','rating'])
len(df)
df.head()
# Out:
#                 business_name                            lic_code  \
# 1           sizzling pot king       Restaurant 1,000 - 2,000 Sqft
# 4      new york pizza kitchen                                 NaN
# 6       joint venture kitchen       Restaurant 1,000 - 2,000 Sqft
# 11  yan yan seafood resaurant  Restaurant Greater Than 2,000 Sqft
# 16                   mr bread     Restaurant Less Than 1,000 Sqft
#
#      street_address business_start_date business_end_date  Lifespan isClosed  \
# 1        139 8th st          2017-12-28               NaN     221.0       no
# 4       127 eddy st          2016-03-16        2017-03-14     363.0      yes
# 6   167 11th street          2017-06-26               NaN     406.0       no
# 11    2241 judah st          2014-07-01               NaN    1497.0       no
# 16  1018 taraval st          2018-01-02               NaN     216.0       no
#
#                                  full_address  business_id  \
# 1        139 8th st, San Francisco, CA, 94103        94408
# 4       127 eddy st, San Francisco, CA, 94102        91028
# 6   167 11th street, San Francisco, CA, 94103        92980
# 11    2241 judah st, San Francisco, CA, 94122        79565
# 16  1018 taraval st, San Francisco, CA, 94116        94616
#
#                           name   ...   HD02_S171  HD02_S180  HD02_S181  \
# 1            sizzling pot king   ...        18.4      100.0        9.4
# 4       new york pizza kitchen   ...        12.4      100.0        2.5
# 6        joint venture kitchen   ...        18.4      100.0        9.4
# 11  yan yan seafood restaurant   ...         4.2      100.0       50.1
# 16                    mr bread   ...         5.5      100.0       55.7
#
#     HD02_S184  Opening_year Closing_year  Opening_month Closing_month  \
# 1        90.6          2017          NaN             12           NaN
# 4        97.5          2016       2017.0              3           3.0
# 6        90.6          2017          NaN              6           NaN
# 11       49.9          2014          NaN              7           NaN
# 16       44.3          2018          NaN              1           NaN
#
#     price_level  rating
# 1           2.0     4.3
# 4           1.0     3.8
# 6           3.0     4.7
# 11          1.0     4.0
# 16          1.0     4.7
#
# [5 rows x 111 columns]

# %%
print('-------------------Filter Data Summary---------------------')
print('**********************************************************************')
print('--------------------Number of Openings, 2010-2018---------------------')
print(df.groupby('Opening_year').size())
print('--------------------Number of Closures, 2010-2018---------------------')
print(df.groupby('Closing_year').size())
print('----------------Count of restaurants openings, by districts--------------------')
df_openLocations = df[df['isClosed'] == "no"]
print(pd.value_counts(df_openLocations['district'].values, sort=True))
print('----------------Count of restaurants closures, by districts--------------------')
df_closedLocations = df[df['isClosed'] == "yes"]
print(pd.value_counts(df_closedLocations['district'].values, sort=True))
print('----------------------------------------------------------------------')
print('Restaurants "Chains", i.e. with multiple locations. NOT DUPLICATES')
df['lic_code'] = df['lic_code'].groupby(df['business_name']).ffill() # Assigns LIC_Code to matching locations (ex: there might be 3 restaurants with the same name, a chain in these cases, and only one of those will have a LIC.)
print(df.groupby('business_name').filter(lambda x: len(x) > 2).sort_values(by ='business_name',ascending=False))
print('--------------------Count of restaurants, by type---------------------')
print(pd.value_counts(df['lic_code'].values, sort=True))
print('--------------------Count of Ratings, by type---------------------')
print(pd.value_counts(df['rating'].values, sort=True))
print('--------------------Count of Price Ranges, by type---------------------')
print(pd.value_counts(df['price_level'].values, sort=True))
# Out:
# -------------------Filter Data Summary---------------------
# **********************************************************************
# --------------------Number of Openings, 2010-2018---------------------
# Opening_year
# 2010    62
# 2011    76
# 2012    78
# 2013    95
# 2014    90
# 2015    98
# 2016    99
# 2017    57
# 2018    26
# dtype: int64
# --------------------Number of Closures, 2010-2018---------------------
# Closing_year
# 2015.0     8
# 2016.0    14
# 2017.0    29
# 2018.0     7
# dtype: int64
# ----------------Count of restaurants openings, by districts--------------------
# Mission                         53
# South of Market                 48
# Financial District              45
# Inner Richmond                  33
# Tenderloin                      32
# Chinatown                       32
# Outer Sunset                    24
# Outer Richmond                  22
# Lower Nob Hill                  22
# Polk Gulch                      14
# Inner Sunset                    13
# North Beach                     12
# Excelsior                       12
# Union Street                    12
# Mission Dolores                 12
# Parkside                        12
# Castro                          11
# Japantown                       11
# Bernal Heights                  10
# Marina                           9
# Hayes Valley                     9
# Civic Center                     9
# Downtown / Union Square          8
# Russian Hill                     8
# Fishermans Wharf                 8
# Parkmerced                       8
# Western Addition                 8
# Noe Valley                       8
# Cathedral Hill                   8
# Portola                          7
#                                 ..
# Crocker Amazon                   3
# Cayuga                           3
# Laurel Heights / Jordan Park     3
# Potrero Hill                     3
# Lakeshore                        2
# South Beach                      2
# Rincon Hill                      2
# Apparel City                     2
# Parnassus Heights                2
# Cole Valley                      2
# Bayview                          2
# Glen Park                        2
# Outer Mission                    2
# Holly Park                       1
# Showplace Square                 1
# Sunnyside                        1
# Dolores Heights                  1
# Duboce Triangle                  1
# Presidio Heights                 1
# Hunters Point                    1
# Forest Hill                      1
# Golden Gate Park                 1
# Eureka Valley                    1
# Dogpatch                         1
# Pacific Heights                  1
# Visitacion Valley                1
# Presidio Terrace                 1
# Cow Hollow                       1
# Miraloma Park                    1
# Ingleside Terraces               1
# Length: 71, dtype: int64
# ----------------Count of restaurants closures, by districts--------------------
# Mission                    6
# Tenderloin                 5
# Parkmerced                 4
# Financial District         3
# Potrero Hill               3
# Chinatown                  3
# Downtown / Union Square    3
# Haight Ashbury             3
# Bayview                    2
# Fishermans Wharf           2
# Mission Dolores            2
# Castro                     2
# Outer Sunset               2
# Lower Nob Hill             2
# South of Market            2
# Dolores Heights            1
# Ingleside                  1
# Glen Park                  1
# Union Street               1
# Inner Sunset               1
# North Beach                1
# Lower Pacific Heights      1
# Japantown                  1
# Visitacion Valley          1
# Duboce Triangle            1
# Pacific Heights            1
# Inner Richmond             1
# Civic Center               1
# Outer Richmond             1
# dtype: int64
# ----------------------------------------------------------------------
# Restaurants "Chains", i.e. with multiple locations. NOT DUPLICATES
#                   business_name                            lic_code  \
# 1223     wise sons delicatessen       Restaurant 1,000 - 2,000 Sqft
# 1766     wise sons delicatessen       Restaurant 1,000 - 2,000 Sqft
# 2152     wise sons delicatessen     Restaurant Less Than 1,000 Sqft
# 171                    the melt                                 NaN
# 1107                   the melt                                 NaN
# 2071                   the melt  Restaurant Greater Than 2,000 Sqft
# 1787                proper food              Take-Out Establishment
# 1832                proper food              Take-Out Establishment
# 1867                proper food     Restaurant Less Than 1,000 Sqft
# 867                 mixt greens       Restaurant 1,000 - 2,000 Sqft
# 1889                mixt greens       Restaurant 1,000 - 2,000 Sqft
# 1957                mixt greens  Restaurant Greater Than 2,000 Sqft
# 2050                mixt greens       Restaurant 1,000 - 2,000 Sqft
# 33    easy breezy frozen yogurt       Restaurant 1,000 - 2,000 Sqft
# 1344  easy breezy frozen yogurt     Restaurant Less Than 1,000 Sqft
# 2226  easy breezy frozen yogurt     Restaurant Less Than 1,000 Sqft
#
#              street_address business_start_date business_end_date  Lifespan  \
# 1223           3150 24th st          2010-12-25               NaN    2781.0
# 1766       1520 fillmore st          2010-12-25               NaN    2781.0
# 2152         537 octavia st          2010-12-25               NaN    2781.0
# 171   455 market st ste 140          2011-04-12               NaN    2673.0
# 1107  115 new montgomery st          2011-04-12               NaN    2673.0
# 2071          925 market st          2011-04-12               NaN    2673.0
# 1787      350 california st          2013-05-17               NaN    1907.0
# 1832      655 montgomery st          2013-05-17               NaN    1907.0
# 1867             235 2nd st          2013-05-17               NaN    1907.0
# 867     475 sansome st 1005          2012-01-04               NaN    2406.0
# 1889          240 kearny st          2012-01-04               NaN    2406.0
# 1957    51 yerba buena lane          2012-01-04               NaN    2406.0
# 2050       3130 fillmore st          2012-01-04               NaN    2406.0
# 33       44 west portal ave          2012-04-20               NaN    2299.0
# 1344          718 irving st          2012-04-20               NaN    2299.0
# 2226         4028 24th st 2          2012-04-20               NaN    2299.0
#
#      isClosed                                     full_address  business_id  \
# 1223       no            3150 24th st, San Francisco, CA, 9411        68173
# 1766       no       1520 fillmore st, San Francisco, CA, 94115        83804
# 2152       no         537 octavia st, San Francisco, CA, 94102        93022
# 171        no  455 market st ste 140, San Francisco, CA, 94105        93080
# 1107       no  115 new montgomery st, San Francisco, CA, 94105        89128
# 2071       no          925 market st, San Francisco, CA, 94103        90214
# 1787       no      350 california st, San Francisco, CA, 94104        83927
# 1832       no      655 montgomery st, San Francisco, CA, 94111        86960
# 1867       no             235 2nd st, San Francisco, CA, 94105        87624
# 867        no    475 sansome st 1005, San Francisco, CA, 94111        68345
# 1889       no          240 kearny st, San Francisco, CA, 94108        88134
# 1957       no    51 yerba buena lane, San Francisco, CA, 94103        90583
# 2050       no       3130 fillmore st, San Francisco, CA, 94123        92444
# 33         no     44 west portal ave, San Francisco, CA, 94127        94555
# 1344       no          718 irving st, San Francisco, CA, 94122        74756
# 2226       no         4028 24th st 2, San Francisco, CA, 94114        69069
#
#                            name   ...   HD02_S171  HD02_S180  HD02_S181  \
# 1223             wise sons deli   ...         6.0      100.0       19.6
# 1766     wise sons delicatessen   ...         5.3      100.0       24.3
# 2152     wise sons delicatessen   ...         8.5      100.0        9.7
# 171            the organic coup   ...        17.8      100.0       37.2
# 1107                   the bird   ...        17.8      100.0       37.2
# 2071                   the melt   ...        18.4      100.0        9.4
# 1787                proper food   ...        28.5      100.0        8.6
# 1832                proper food   ...         9.2      100.0        3.7
# 1867                proper food   ...        17.8      100.0       37.2
# 867                 mixt greens   ...         9.2      100.0        3.7
# 1889                mixt greens   ...        28.5      100.0        8.6
# 1957                mixt greens   ...        17.8      100.0       37.2
# 2050                mixt greens   ...         8.7      100.0       18.0
# 33    easy breezy frozen yogurt   ...         7.3      100.0       77.7
# 1344  easy breezy frozen yogurt   ...         6.5      100.0       22.1
# 2226                easy breezy   ...         8.6      100.0       43.4
#
#       HD02_S184  Opening_year Closing_year  Opening_month Closing_month  \
# 1223       80.4          2010          NaN             12           NaN
# 1766       75.7          2010          NaN             12           NaN
# 2152       90.3          2010          NaN             12           NaN
# 171        62.8          2011          NaN              4           NaN
# 1107       62.8          2011          NaN              4           NaN
# 2071       90.6          2011          NaN              4           NaN
# 1787       91.4          2013          NaN              5           NaN
# 1832       96.3          2013          NaN              5           NaN
# 1867       62.8          2013          NaN              5           NaN
# 867        96.3          2012          NaN              1           NaN
# 1889       91.4          2012          NaN              1           NaN
# 1957       62.8          2012          NaN              1           NaN
# 2050       82.0          2012          NaN              1           NaN
# 33         22.3          2012          NaN              4           NaN
# 1344       77.9          2012          NaN              4           NaN
# 2226       56.6          2012          NaN              4           NaN
#
#       price_level  rating
# 1223          2.0     3.4
# 1766          2.0     4.3
# 2152          3.0     4.3
# 171           2.0     4.2
# 1107          2.0     4.4
# 2071          2.0     3.7
# 1787          1.0     4.3
# 1832          2.0     3.7
# 1867          2.0     4.3
# 867           1.0     4.2
# 1889          2.0     4.0
# 1957          1.0     3.8
# 2050          2.0     4.2
# 33            1.0     4.0
# 1344          1.0     4.8
# 2226          2.0     4.0
#
# [16 rows x 111 columns]
# --------------------Count of restaurants, by type---------------------
# Restaurant 1,000 - 2,000 Sqft         263
# Restaurant Less Than 1,000 Sqft       186
# Restaurant Greater Than 2,000 Sqft     77
# Take-Out Establishment                 26
# Fast Food Extablishment                 7
# dtype: int64
# --------------------Count of Ratings, by type---------------------
# 4.3    111
# 4.2     98
# 4.4     89
# 4.5     73
# 4.6     55
# 4.0     54
# 4.1     54
# 3.9     42
# 3.8     23
# 4.7     18
# 3.7     15
# 4.8     10
# 3.6      9
# 3.4      7
# 3.5      6
# 3.3      5
# 3.1      4
# 4.9      2
# 2.0      2
# 2.8      1
# 3.0      1
# 2.7      1
# 3.2      1
# dtype: int64
# --------------------Count of Price Ranges, by type---------------------
# 1.0    336
# 2.0    306
# 3.0     27
# 4.0     12
# dtype: int64

# %%
# dfN['business_name'].unique()
# df = df.dropna(subset=['lic_code']) # Remove NaN values in 'lic_code'
len(df)
# Out:
# 681

# %%
# https://seaborn.pydata.org/tutorial/categorical.html
Cmonths = df["Closing_month"].dropna()
Cyears = df["Closing_year"].dropna()
sns.distplot(df["Opening_year"])
sns.distplot(Cyears)

# %%
sns.jointplot(x='Lifespan', y='HC03_VC156', data = df);

# %%
sns.catplot(x="Opening_year", y="HC01_VC36", hue="lic_code",
            col="isClosed", aspect=.6,
            kind="swarm", data=df);

# HC01_VC36 is mean travel time for workers (census tract level) in minutes

# %%
sns.catplot(x="Opening_year", hue="lic_code", kind="count",
            palette="pastel", edgecolor=".6",
            data=df);

# %%
####################################### Regression Testing ########################################################33

# %%
# One Hot-Encoding binary (True/False variables)
    # https://stackoverflow.com/questions/34007308/linear-regression-analysis-with-string-categorical-features-variables
    # https://www.kaggle.com/getting-started/27270

df['isClosed'] = pd.get_dummies(df['isClosed']) # no: 1, yes: 0

df['price_level'] = df['price_level'].round(0).astype(int) # No need for encoding, just convert to int.
# Out:
# 1       2
# 4       1
# 6       3
# 11      1
# 16      1
# 18      2
# 19      1
# 21      1
# 22      1
# 30      2
# 32      2
# 33      1
# 36      1
# 44      2
# 46      1
# 50      2
# 52      2
# 58      1
# 59      2
# 63      2
# 66      1
# 67      1
# 72      2
# 74      2
# 75      1
# 77      1
# 82      1
# 96      1
# 131     1
# 132     2
#        ..
# 2119    1
# 2122    4
# 2124    1
# 2129    1
# 2130    1
# 2133    2
# 2142    2
# 2143    2
# 2146    2
# 2147    2
# 2149    1
# 2152    3
# 2153    2
# 2154    1
# 2156    2
# 2157    2
# 2160    2
# 2161    2
# 2166    1
# 2211    1
# 2212    1
# 2213    2
# 2215    3
# 2218    2
# 2220    1
# 2222    1
# 2223    2
# 2224    2
# 2225    2
# 2226    2
# Name: price_level, Length: 681, dtype: int32

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 3))
plt.hist(df.Lifespan)
plt.xlabel('Lifespan (Days)')
plt.ylabel('count')
plt.tight_layout()

plt.figure(figsize=(8, 3))
plt.hist(df.MA)
plt.xlabel('Healthscores')
plt.ylabel('count')
plt.tight_layout()

plt.figure(figsize=(8, 3))
plt.hist(df.HD01_S001)
plt.xlabel('Population by Tracts')
plt.ylabel('count')
plt.tight_layout()

plt.figure(figsize=(8, 3))
plt.hist(df.Opening_year)
plt.xlabel('Opening Year')
plt.ylabel('count')
plt.tight_layout()

plt.figure(figsize=(8, 3))
plt.hist(df.price_level.dropna())
plt.xlabel('Price Levels')
plt.ylabel('count')
plt.tight_layout()

plt.figure(figsize=(8, 3))
plt.hist(df.rating.dropna())
plt.xlabel('Ratings (from Google)')
plt.ylabel('count')
plt.tight_layout()

# %%
# Reference: https://www.scipy-lectures.org/packages/scikit-learn/auto_examples/plot_boston_prediction.html#sphx-glr-packages-scikit-learn-auto-examples-plot-boston-prediction-py
# https://stackoverflow.com/questions/28334091/turning-a-pandas-dataframe-to-an-array-and-evaluate-multiple-linear-regression-m
from sklearn.linear_model import LinearRegression
df.shape
X = df[['price_level','rating','MA','isClosed']].as_matrix()
y =df['Lifespan'].values
model = LinearRegression()
model.fit(X, y)
# Out:
# C:\Users\White Base\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)
expected = y_test

plt.figure(figsize=(8, 6))
plt.scatter(expected, predicted)
plt.plot([0, 3500], [0, 3500], '--k')
plt.axis('tight')
plt.xlabel('True Lifespan')
plt.ylabel('Predicted Lifespan')
plt.tight_layout()

# %%
https://www.scipy-lectures.org/packages/statistics/auto_examples/plot_wage_education_gender.html
http://andrewgaidus.com/Spatial_Econonometric_Modeling/
http://darribas.org/gds_scipy16/ipynb_md/08_spatial_regression.html
http://people.duke.edu/~rnau/testing.htm
https://towardsdatascience.com/simple-and-multiple-linear-regression-in-python-c928425168f9
