# %%
import numpy as np
import pandas as pd
import os

# %%
#Set the paths
registered_business_path = os.path.join('Cleaned Datasets', 'cleaned_registered_businesses.csv')
health_scores_path = os.path.join('Cleaned Datasets', 'health_scores.csv')

registered_business_df = pd.read_csv(registered_business_path)
health_scores_df = pd.read_csv(health_scores_path)

# %%
registered_business_df.head(10)
len(registered_business_df)
# Out:
# 223102

# %%
#lower the name of the business and street address
registered_business_df['business_name'] = registered_business_df['business_name'].str.lower()
registered_business_df['street_address'] = registered_business_df['street_address'].str.lower()

#Drop any business_name or street_address that has null values
registered_business_df['street_address'].replace('', np.nan, inplace=True)
registered_business_df = registered_business_df.dropna(subset=['street_address'])

#Convert street address column to string 
registered_business_df['street_address'] = registered_business_df['street_address'].astype(str)

registered_business_df.head(1)
len(registered_business_df)
# Out:
# 223098

# %%
#remove the whitespaces at the end of business and street address
registered_business_df['business_name'] = registered_business_df['business_name'].str.strip()
registered_business_df['street_address'] = registered_business_df['street_address'].str.strip()

registered_business_df.head(1)
# Out:
#                   business_name                               category  \
# 0  blossoming lotus acupuncture  Private Education and Health Services
#
#   lic_code         street_address State           City  zipcode  \
# 0      NaN  2670 leavenworth st a    CA  San Francisco  94109.0
#
#   business_start_date business_end_date neighborhoods  \
# 0          01/28/2010               NaN   North Beach
#
#                                   business_location  supervisor_district  \
# 0  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n                  2.0
#
#    Lifespan closed  age_if_opened
# 0       NaN     no         3107.0

# %%
registered_business_df.head(1)
# Out:
#                   business_name                               category  \
# 0  blossoming lotus acupuncture  Private Education and Health Services
#
#   lic_code         street_address State           City  zipcode  \
# 0      NaN  2670 leavenworth st a    CA  San Francisco  94109.0
#
#   business_start_date business_end_date neighborhoods  \
# 0          01/28/2010               NaN   North Beach
#
#                                   business_location  supervisor_district  \
# 0  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n                  2.0
#
#    Lifespan closed  age_if_opened
# 0       NaN     no         3107.0

# %%
# replace ', ", -, etc
registered_business_df['business_name'] = registered_business_df['business_name'].str.replace(r"[\"\',-.@!$%^&*]", '')

#get the first 2 words from street address
registered_business_df['formatted_address'] = registered_business_df['street_address'].str.split().str[0] + " " + registered_business_df['street_address'].str.split().str[1]
registered_business_df['formatted_name'] = registered_business_df['business_name'].str.split().str[0]

#drop the null formatted addresses 
registered_business_df = registered_business_df.dropna(subset=['formatted_address'])

#create a unique id based off the formatted address and name
registered_business_df['uniqueid'] = registered_business_df['formatted_name'] + registered_business_df['formatted_address']


registered_business_df.head(1)
# Out:
#                   business_name                               category  \
# 0  blossoming lotus acupuncture  Private Education and Health Services
#
#   lic_code         street_address State           City  zipcode  \
# 0      NaN  2670 leavenworth st a    CA  San Francisco  94109.0
#
#   business_start_date business_end_date neighborhoods  \
# 0          01/28/2010               NaN   North Beach
#
#                                   business_location  supervisor_district  \
# 0  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n                  2.0
#
#    Lifespan closed  age_if_opened formatted_address formatted_name  \
# 0       NaN     no         3107.0  2670 leavenworth     blossoming
#
#                      uniqueid
# 0  blossoming2670 leavenworth

# %% [markdown]
# # Clean up the health scores dataset

# %%
health_scores_df.head(10)
# Out:
#    business_id                                name  \
# 0           19               NRGIZE LIFESTYLE CAFE
# 1           19               NRGIZE LIFESTYLE CAFE
# 2           19               NRGIZE LIFESTYLE CAFE
# 3           24  OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 4           24  OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 5           24  OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 6           31      NORMAN'S ICE CREAM AND FREEZES
# 7           31      NORMAN'S ICE CREAM AND FREEZES
# 8           45                 CHARLIE'S DELI CAFE
# 9           45                 CHARLIE'S DELI CAFE
#
#                          address           city state postal_code   latitude  \
# 0   1200 VAN NESS AVE, 3RD FLOOR  San Francisco    CA       94109  37.786848
# 1   1200 VAN NESS AVE, 3RD FLOOR  San Francisco    CA       94109  37.786848
# 2   1200 VAN NESS AVE, 3RD FLOOR  San Francisco    CA       94109  37.786848
# 3  500 CALIFORNIA ST, 2ND  FLOOR  San Francisco    CA       94104  37.792888
# 4  500 CALIFORNIA ST, 2ND  FLOOR  San Francisco    CA       94104  37.792888
# 5  500 CALIFORNIA ST, 2ND  FLOOR  San Francisco    CA       94104  37.792888
# 6           2801 LEAVENWORTH ST   San Francisco    CA       94133  37.807155
# 7           2801 LEAVENWORTH ST   San Francisco    CA       94133  37.807155
# 8                3202 FOLSOM ST   San Francisco    CA       94110  37.747114
# 9                3202 FOLSOM ST   San Francisco    CA       94110  37.747114
#
#     longitude phone_number  score        date     type    year  month
# 0 -122.421547  14157763262   94.0  2017-12-11  routine  2017.0   12.0
# 1 -122.421547  14157763262   96.0  2018-06-07  routine  2018.0    6.0
# 2 -122.421547  14157763262   94.0  2016-05-13  routine  2016.0    5.0
# 3 -122.403135  14156779494   96.0  2016-03-11  routine  2016.0    3.0
# 4 -122.403135  14156779494   98.0  2016-10-05  routine  2016.0   10.0
# 5 -122.403135  14156779494   98.0  2017-11-01  routine  2017.0   11.0
# 6 -122.419004          NaN   98.0  2015-12-04  routine  2015.0   12.0
# 7 -122.419004          NaN   96.0  2018-06-15  routine  2018.0    6.0
# 8 -122.413641  14156415051   85.0  2017-09-14  routine  2017.0    9.0
# 9 -122.413641  14156415051   88.0  2018-05-29  routine  2018.0    5.0

# %%
#lower the name of the business and street address
health_scores_df['name'] = health_scores_df['name'].str.lower()
health_scores_df['address'] = health_scores_df['address'].str.lower()

#Drop any street_address that has null values
health_scores_df['address'].replace('', np.nan, inplace=True)
health_scores_df = health_scores_df.dropna(subset=['address'])

#Convert street address column to string 
health_scores_df['address'] = health_scores_df['address'].astype(str)

registered_business_df.head(1)
len(registered_business_df)
# Out:
# 223033

# %%
#remove the whitespaces at the end of business and street address
health_scores_df['name'] = health_scores_df['name'].str.strip()
health_scores_df['address'] = health_scores_df['address'].str.strip()

health_scores_df.head(1)
# Out:
#    business_id                   name                       address  \
# 0           19  nrgize lifestyle cafe  1200 van ness ave, 3rd floor
#
#             city state postal_code   latitude   longitude phone_number  score  \
# 0  San Francisco    CA       94109  37.786848 -122.421547  14157763262   94.0
#
#          date     type    year  month
# 0  2017-12-11  routine  2017.0   12.0

# %%
# replace ', ", -, etc
health_scores_df['name'] = health_scores_df['name'].str.replace(r"[\"\',-.@!$%^&*]", '')

#get the first 2 words from street address
health_scores_df['formatted_address'] = health_scores_df['address'].str.split().str[0] + " " + health_scores_df['address'].str.split().str[1]
health_scores_df['formatted_name'] = health_scores_df['name'].str.split().str[0]

#drop the null formatted addresses 
health_scores_df = health_scores_df.dropna(subset=['formatted_address'])

#create a unique id based off the formatted address and name
health_scores_df['uniqueid'] = health_scores_df['formatted_name'] + health_scores_df['formatted_address']

# %%
#get the columns we need
health_scores_df = health_scores_df[['business_id', 'name', 'score', 'year', 'formatted_address', 'formatted_name', 'latitude', 'longitude', 'uniqueid']]


len(health_scores_df)

# health_scores_df.head(1000)
# Out:
# 14859

# %%
#Merge the registered business df with the geocodes to get unique location id
merged = registered_business_df.merge(health_scores_df, on='uniqueid')

merged = merged[merged['category'] == 'Food Services']
len(merged)
# Out:
# 9828

# %%
merged.head(100)
# Out:
#                    business_name       category  \
# 0              yokai express inc  Food Services
# 1              sizzling pot king  Food Services
# 2              sizzling pot king  Food Services
# 3    burma super star restaurant  Food Services
# 4    burma super star restaurant  Food Services
# 11                  ikes kitchen  Food Services
# 12               foundation cafe  Food Services
# 15        new york pizza kitchen  Food Services
# 16        new york pizza kitchen  Food Services
# 17        new york pizza kitchen  Food Services
# 18        new york pizza kitchen  Food Services
# 19      corner bakery cafe #1584  Food Services
# 20      corner bakery cafe #1584  Food Services
# 21       corner bakery cafe #106  Food Services
# 22       corner bakery cafe #106  Food Services
# 23       corner bakery cafe #106  Food Services
# 24       corner bakery cafe #106  Food Services
# 25                   the cordial  Food Services
# 27             sorrel restaurant  Food Services
# 28           new fortune dim sum  Food Services
# 29        new fortune restaurant  Food Services
# 31           new fortune dim sum  Food Services
# 32               braised + bread  Food Services
# 33      marina round table pizza  Food Services
# 34        hayes valley bakeworks  Food Services
# 35                 freshway fish  Food Services
# 36    avedanos holly park market  Food Services
# 37         joint venture kitchen  Food Services
# 38    there sushibar  restaurant  Food Services
# 47       uber  atg (bon appetit)  Food Services
# ..                           ...            ...
# 184                    jacks bar  Food Services
# 185                    jacks bar  Food Services
# 186                    jacks bar  Food Services
# 187                jacks cannery  Food Services
# 188                jacks cannery  Food Services
# 189                jacks cannery  Food Services
# 214                     clooneys  Food Services
# 215                     clooneys  Food Services
# 216                     clooneys  Food Services
# 220             mcdonalds #11742  Food Services
# 221             mcdonalds #11742  Food Services
# 222             mcdonalds #11742  Food Services
# 223                    mcdonalds  Food Services
# 224                    mcdonalds  Food Services
# 225                    mcdonalds  Food Services
# 226                   sushi shoh  Food Services
# 228                   sushi shoh  Food Services
# 229                   sushi shoh  Food Services
# 230                   sushi shoh  Food Services
# 231                gochees pizza  Food Services
# 431          peaches patties llc  Food Services
# 432          peaches patties llc  Food Services
# 433          peaches patties llc  Food Services
# 434              peaches patties  Food Services
# 435              peaches patties  Food Services
# 436              peaches patties  Food Services
# 437          peaches patties llc  Food Services
# 438          peaches patties llc  Food Services
# 439          peaches patties llc  Food Services
# 440          peaches patties llc  Food Services
#
#                                           lic_code  \
# 0                                              NaN
# 1                    Restaurant 1,000 - 2,000 Sqft
# 2                    Restaurant 1,000 - 2,000 Sqft
# 3                    Restaurant 1,000 - 2,000 Sqft
# 4                    Restaurant 1,000 - 2,000 Sqft
# 11              Restaurant Greater Than 2,000 Sqft
# 12                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                 Restaurant Less Than 1,000 Sqft
# 18                 Restaurant Less Than 1,000 Sqft
# 19   Places Of Public Assembly & Open-Air Assembly
# 20   Places Of Public Assembly & Open-Air Assembly
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 27                                        Multiple
# 28                                             NaN
# 29                 Restaurant Less Than 1,000 Sqft
# 31                                             NaN
# 32                   Restaurant 1,000 - 2,000 Sqft
# 33                   Restaurant 1,000 - 2,000 Sqft
# 34                          Take-Out Establishment
# 35                    Caterer Retail Food Vehicles
# 36    Retail Food Market W/food Prep. Lt 5001 Sqft
# 37                   Restaurant 1,000 - 2,000 Sqft
# 38              Restaurant Greater Than 2,000 Sqft
# 47                 Employee Cafeterias W/food Prep
# ..                                             ...
# 184  Places Of Public Assembly & Open-Air Assembly
# 185  Places Of Public Assembly & Open-Air Assembly
# 186  Places Of Public Assembly & Open-Air Assembly
# 187             Restaurant Greater Than 2,000 Sqft
# 188             Restaurant Greater Than 2,000 Sqft
# 189             Restaurant Greater Than 2,000 Sqft
# 214                  Restaurant 1,000 - 2,000 Sqft
# 215                  Restaurant 1,000 - 2,000 Sqft
# 216                  Restaurant 1,000 - 2,000 Sqft
# 220                                            NaN
# 221                                            NaN
# 222                                            NaN
# 223                                       Multiple
# 224                                       Multiple
# 225                                       Multiple
# 226                                            NaN
# 228                                            NaN
# 229                                            NaN
# 230                  Restaurant 1,000 - 2,000 Sqft
# 231                                            NaN
# 431                                            NaN
# 432                                            NaN
# 433                                            NaN
# 434                                        Caterer
# 435                                        Caterer
# 436                                        Caterer
# 437                                            NaN
# 438                                            NaN
# 439                                            NaN
# 440                                            NaN
#
#                  street_address State           City  zipcode  \
# 0           135 4th st ste 4000    CA  San Francisco  94103.0
# 1                    139 8th st    CA  San Francisco  94103.0
# 2                    139 8th st    CA  San Francisco  94103.0
# 3                309 clement st    CA  San Francisco  94118.0
# 4                309 clement st    CA  San Francisco  94118.0
# 11        800 van ness ave bldg    CA  San Francisco  94109.0
# 12                   645 5th st    CA  San Francisco  94107.0
# 15                  127 eddy st    CA  San Francisco  94102.0
# 16                  127 eddy st    CA  San Francisco  94102.0
# 17                  127 eddy st    CA  San Francisco  94102.0
# 18                  127 eddy st    CA  San Francisco  94102.0
# 19                665 market st    CA  San Francisco  94105.0
# 20                665 market st    CA  San Francisco  94105.0
# 21                665 market st    CA  San Francisco  94105.0
# 22                665 market st    CA  San Francisco  94105.0
# 23                665 market st    CA  San Francisco  94105.0
# 24                665 market st    CA  San Francisco  94105.0
# 25                163 jessie st    CA  San Francisco  94105.0
# 27           3228 sacramento st    CA  San Francisco  94115.0
# 28              811 stockton st    CA  San Francisco  94108.0
# 29              811 stockton st    CA  San Francisco  94108.0
# 31              811 stockton st    CA  San Francisco  94108.0
# 32          50 post st unit 65a    CA  San Francisco  94104.0
# 33          1503 north point st    CA  San Francisco  94123.0
# 34          525 golden gate ave    CA  San Francisco  94102.0
# 35             699 columbus ave    CA  San Francisco  94133.0
# 36           2057 divisadero st    CA  San Francisco  94115.0
# 37              167 11th street    CA  San Francisco  94103.0
# 38                   393 bay st    CA  San Francisco  94133.0
# 47          575 20th st 113 1fl    CA  San Francisco  94301.0
# ..                          ...   ...            ...      ...
# 184  2801 leavenworth st j31-32    CA  San Francisco  94133.0
# 185  2801 leavenworth st j31-32    CA  San Francisco  94133.0
# 186  2801 leavenworth st j31-32    CA  San Francisco  94133.0
# 187         2801 leavenworth st    CA  San Francisco  94133.0
# 188         2801 leavenworth st    CA  San Francisco  94133.0
# 189         2801 leavenworth st    CA  San Francisco  94133.0
# 214            1401 valencia st    CA  San Francisco  94110.0
# 215            1401 valencia st    CA  San Francisco  94110.0
# 216            1401 valencia st    CA  San Francisco  94110.0
# 220              255 winston dr    CA  San Francisco  94132.0
# 221              255 winston dr    CA  San Francisco  94132.0
# 222              255 winston dr    CA  San Francisco  94132.0
# 223         255 winston dr unit    CA  San Francisco  94132.0
# 224         255 winston dr unit    CA  San Francisco  94132.0
# 225         255 winston dr unit    CA  San Francisco  94132.0
# 226              406 dewey blvd    CA  San Francisco  94116.0
# 228                406 dewey bl    CA  San Francisco  94116.0
# 229              406 dewey blvd    CA  San Francisco  94116.0
# 230              406 dewey blvd    CA  San Francisco  94116.0
# 231   2 embarcadero ctr unit b6    CA  San+francisco  94111.0
# 431              2948 folsom st    CA  San Francisco  94110.0
# 432              2948 folsom st    CA  San Francisco  94110.0
# 433              2948 folsom st    CA  San Francisco  94110.0
# 434              2948 folsom st    CA  San Francisco  94110.0
# 435              2948 folsom st    CA  San Francisco  94110.0
# 436              2948 folsom st    CA  San Francisco  94110.0
# 437            331 cortland ave    CA  San Francisco  94110.0
# 438            331 cortland ave    CA  San Francisco  94110.0
# 439            331 cortland ave    CA  San Francisco  94110.0
# 440            331 cortland ave    CA  San Francisco  94110.0
#
#     business_start_date business_end_date                   neighborhoods  \
# 0            12/28/2017               NaN  Financial District/South Beach
# 1            12/28/2017               NaN                 South of Market
# 2            12/28/2017               NaN                 South of Market
# 3            03/01/2001               NaN                  Inner Richmond
# 4            03/01/2001               NaN                  Inner Richmond
# 11           12/21/2017               NaN                      Tenderloin
# 12           12/15/2017               NaN                             NaN
# 15           03/16/2016        03/14/2017                             NaN
# 16           03/16/2016        03/14/2017                             NaN
# 17           03/14/2017               NaN                             NaN
# 18           03/14/2017               NaN                             NaN
# 19           05/01/2015               NaN                             NaN
# 20           05/01/2015               NaN                             NaN
# 21           07/08/2014        04/30/2015                             NaN
# 22           07/08/2014        04/30/2015                             NaN
# 23           05/01/2015               NaN                             NaN
# 24           05/01/2015               NaN                             NaN
# 25           01/02/2018               NaN                             NaN
# 27           01/01/2018               NaN                             NaN
# 28           01/01/2018               NaN                             NaN
# 29           01/01/2018               NaN                             NaN
# 31           01/01/2012        01/01/2018                       Chinatown
# 32           01/02/2018               NaN  Financial District/South Beach
# 33           01/01/2018               NaN                          Marina
# 34           06/01/2012               NaN                      Tenderloin
# 35           04/23/2018               NaN                             NaN
# 36           04/16/2007               NaN                             NaN
# 37           06/26/2017               NaN                 South of Market
# 38           01/04/2018               NaN                             NaN
# 47           07/01/1987               NaN                    Potrero Hill
# ..                  ...               ...                             ...
# 184          04/01/1998               NaN                    Russian Hill
# 185          04/01/1998               NaN                    Russian Hill
# 186          04/01/1998               NaN                    Russian Hill
# 187          04/01/1998               NaN                    Russian Hill
# 188          04/01/1998               NaN                    Russian Hill
# 189          04/01/1998               NaN                    Russian Hill
# 214          12/01/2003               NaN                             NaN
# 215          12/01/2003               NaN                             NaN
# 216          12/01/2003               NaN                             NaN
# 220          11/01/2001               NaN                             NaN
# 221          11/01/2001               NaN                             NaN
# 222          11/01/2001               NaN                             NaN
# 223          01/01/2016               NaN                       Lakeshore
# 224          01/01/2016               NaN                       Lakeshore
# 225          01/01/2016               NaN                       Lakeshore
# 226          04/26/2018               NaN                             NaN
# 228          05/06/2013        10/17/2016              West of Twin Peaks
# 229          10/17/2016        10/17/2016                             NaN
# 230          10/18/2016        06/28/2018                             NaN
# 231          06/01/2018               NaN                             NaN
# 431          06/01/2018               NaN                             NaN
# 432          06/01/2018               NaN                             NaN
# 433          06/01/2018               NaN                             NaN
# 434          06/13/2014        05/31/2018                             NaN
# 435          06/13/2014        05/31/2018                             NaN
# 436          06/13/2014        05/31/2018                             NaN
# 437          06/01/2018               NaN                             NaN
# 438          06/01/2018               NaN                             NaN
# 439          06/01/2018               NaN                             NaN
# 440          06/01/2018               NaN                             NaN
#
#         ...     formatted_name_x                 uniqueid  business_id  \
# 0       ...                yokai             yokai135 4th        94310
# 1       ...             sizzling          sizzling139 8th        94408
# 2       ...             sizzling          sizzling139 8th        94408
# 3       ...                burma         burma309 clement         1977
# 4       ...                burma         burma309 clement         1977
# 11      ...                 ikes              ikes800 van        94910
# 12      ...           foundation        foundation645 5th        94387
# 15      ...                  new              new127 eddy        91028
# 16      ...                  new              new127 eddy        91028
# 17      ...                  new              new127 eddy        91028
# 18      ...                  new              new127 eddy        91028
# 19      ...               corner         corner665 market        83327
# 20      ...               corner         corner665 market        83327
# 21      ...               corner         corner665 market        83327
# 22      ...               corner         corner665 market        83327
# 23      ...               corner         corner665 market        83327
# 24      ...               corner         corner665 market        83327
# 25      ...                  the            the163 jessie        95877
# 27      ...               sorrel    sorrel3228 sacramento        94604
# 28      ...                  new          new811 stockton        94502
# 29      ...                  new          new811 stockton        94502
# 31      ...                  new          new811 stockton        94502
# 32      ...              braised           braised50 post        94432
# 33      ...               marina         marina1503 north        94689
# 34      ...                hayes          hayes525 golden        94355
# 35      ...             freshway     freshway699 columbus        96410
# 36      ...             avedanos  avedanos2057 divisadero        96575
# 37      ...                joint            joint167 11th        92980
# 38      ...                there             there393 bay        94577
# 47      ...                 uber             uber575 20th        94210
# ..      ...                  ...                      ...          ...
# 184     ...                jacks    jacks2801 leavenworth         3325
# 185     ...                jacks    jacks2801 leavenworth         3325
# 186     ...                jacks    jacks2801 leavenworth         3325
# 187     ...                jacks    jacks2801 leavenworth         3325
# 188     ...                jacks    jacks2801 leavenworth         3325
# 189     ...                jacks    jacks2801 leavenworth         3325
# 214     ...             clooneys    clooneys1401 valencia         2369
# 215     ...             clooneys    clooneys1401 valencia         2369
# 216     ...             clooneys    clooneys1401 valencia         2369
# 220     ...            mcdonalds     mcdonalds255 winston        88524
# 221     ...            mcdonalds     mcdonalds255 winston        88524
# 222     ...            mcdonalds     mcdonalds255 winston        88524
# 223     ...            mcdonalds     mcdonalds255 winston        88524
# 224     ...            mcdonalds     mcdonalds255 winston        88524
# 225     ...            mcdonalds     mcdonalds255 winston        88524
# 226     ...                sushi           sushi406 dewey        96577
# 228     ...                sushi           sushi406 dewey        96577
# 229     ...                sushi           sushi406 dewey        96577
# 230     ...                sushi           sushi406 dewey        96577
# 231     ...              gochees     gochees2 embarcadero        96576
# 431     ...              peaches       peaches2948 folsom        89512
# 432     ...              peaches       peaches2948 folsom        89512
# 433     ...              peaches       peaches2948 folsom        89512
# 434     ...              peaches       peaches2948 folsom        89512
# 435     ...              peaches       peaches2948 folsom        89512
# 436     ...              peaches       peaches2948 folsom        89512
# 437     ...              peaches      peaches331 cortland        89511
# 438     ...              peaches      peaches331 cortland        89511
# 439     ...              peaches      peaches331 cortland        89511
# 440     ...              peaches      peaches331 cortland        89511
#
#                            name  score    year formatted_address_y  \
# 0                 yokai express  100.0  2018.0             135 4th
# 1             sizzling pot king   86.0  2018.0             139 8th
# 2             sizzling pot king   80.0  2018.0             139 8th
# 3    burma superstar restaurant   91.0  2017.0         309 clement
# 4    burma superstar restaurant   87.0  2016.0         309 clement
# 11                 ikes kitchen    NaN     NaN             800 van
# 12              foundation cafe   85.0  2018.0             645 5th
# 15       new york pizza kitchen   85.0  2017.0            127 eddy
# 16       new york pizza kitchen   89.0  2018.0            127 eddy
# 17       new york pizza kitchen   85.0  2017.0            127 eddy
# 18       new york pizza kitchen   89.0  2018.0            127 eddy
# 19     corner bakery cafe #1584   96.0  2017.0          665 market
# 20     corner bakery cafe #1584   96.0  2016.0          665 market
# 21     corner bakery cafe #1584   96.0  2017.0          665 market
# 22     corner bakery cafe #1584   96.0  2016.0          665 market
# 23     corner bakery cafe #1584   96.0  2017.0          665 market
# 24     corner bakery cafe #1584   96.0  2016.0          665 market
# 25                  the cordial    NaN     NaN          163 jessie
# 27            sorrel restaurant   93.0  2018.0     3228 sacramento
# 28       new fortune restaurant    NaN     NaN        811 stockton
# 29       new fortune restaurant    NaN     NaN        811 stockton
# 31       new fortune restaurant    NaN     NaN        811 stockton
# 32              braised + bread  100.0  2018.0             50 post
# 33     marina round table pizza    NaN     NaN          1503 north
# 34       hayes valley bakeworks    NaN     NaN          525 golden
# 35                freshway fish    NaN     NaN        699 columbus
# 36   avedanos holly park market    NaN     NaN     2057 divisadero
# 37        joint venture kitchen   93.0  2018.0            167 11th
# 38   there sushibar  restaurant   94.0  2018.0             393 bay
# 47      uber  atg (bon appetit)    NaN     NaN            575 20th
# ..                          ...    ...     ...                 ...
# 184               jacks cannery   96.0  2017.0    2801 leavenworth
# 185               jacks cannery   77.0  2016.0    2801 leavenworth
# 186               jacks cannery   83.0  2016.0    2801 leavenworth
# 187               jacks cannery   96.0  2017.0    2801 leavenworth
# 188               jacks cannery   77.0  2016.0    2801 leavenworth
# 189               jacks cannery   83.0  2016.0    2801 leavenworth
# 214                    clooneys   86.0  2017.0       1401 valencia
# 215                    clooneys   83.0  2018.0       1401 valencia
# 216                    clooneys   86.0  2016.0       1401 valencia
# 220                   mcdonalds   96.0  2016.0         255 winston
# 221                   mcdonalds   73.0  2017.0         255 winston
# 222                   mcdonalds   98.0  2018.0         255 winston
# 223                   mcdonalds   96.0  2016.0         255 winston
# 224                   mcdonalds   73.0  2017.0         255 winston
# 225                   mcdonalds   98.0  2018.0         255 winston
# 226                  sushi shoh   92.0  2018.0           406 dewey
# 228                  sushi shoh   92.0  2018.0           406 dewey
# 229                  sushi shoh   92.0  2018.0           406 dewey
# 230                  sushi shoh   92.0  2018.0           406 dewey
# 231               gochees pizza    NaN     NaN       2 embarcadero
# 431             peaches patties  100.0  2016.0         2948 folsom
# 432             peaches patties   93.0  2017.0         2948 folsom
# 433             peaches patties  100.0  2018.0         2948 folsom
# 434             peaches patties  100.0  2016.0         2948 folsom
# 435             peaches patties   93.0  2017.0         2948 folsom
# 436             peaches patties  100.0  2018.0         2948 folsom
# 437             peaches patties  100.0  2017.0        331 cortland
# 438             peaches patties  100.0  2017.0        331 cortland
# 439             peaches patties  100.0  2016.0        331 cortland
# 440             peaches patties  100.0  2018.0        331 cortland
#
#     formatted_name_y   latitude   longitude
# 0              yokai        NaN         NaN
# 1           sizzling        NaN         NaN
# 2           sizzling        NaN         NaN
# 3              burma  37.783004 -122.462539
# 4              burma  37.783004 -122.462539
# 11              ikes        NaN         NaN
# 12        foundation        NaN         NaN
# 15               new        NaN         NaN
# 16               new        NaN         NaN
# 17               new        NaN         NaN
# 18               new        NaN         NaN
# 19            corner        NaN         NaN
# 20            corner        NaN         NaN
# 21            corner        NaN         NaN
# 22            corner        NaN         NaN
# 23            corner        NaN         NaN
# 24            corner        NaN         NaN
# 25               the        NaN         NaN
# 27            sorrel        NaN         NaN
# 28               new        NaN         NaN
# 29               new        NaN         NaN
# 31               new        NaN         NaN
# 32           braised        NaN         NaN
# 33            marina        NaN         NaN
# 34             hayes        NaN         NaN
# 35          freshway        NaN         NaN
# 36          avedanos        NaN         NaN
# 37             joint        NaN         NaN
# 38             there        NaN         NaN
# 47              uber        NaN         NaN
# ..               ...        ...         ...
# 184            jacks  37.807155 -122.419004
# 185            jacks  37.807155 -122.419004
# 186            jacks  37.807155 -122.419004
# 187            jacks  37.807155 -122.419004
# 188            jacks  37.807155 -122.419004
# 189            jacks  37.807155 -122.419004
# 214         clooneys  37.750374 -122.420456
# 215         clooneys  37.750374 -122.420456
# 216         clooneys  37.750374 -122.420456
# 220        mcdonalds        NaN         NaN
# 221        mcdonalds        NaN         NaN
# 222        mcdonalds        NaN         NaN
# 223        mcdonalds        NaN         NaN
# 224        mcdonalds        NaN         NaN
# 225        mcdonalds        NaN         NaN
# 226            sushi        NaN         NaN
# 228            sushi        NaN         NaN
# 229            sushi        NaN         NaN
# 230            sushi        NaN         NaN
# 231          gochees        NaN         NaN
# 431          peaches        NaN         NaN
# 432          peaches        NaN         NaN
# 433          peaches        NaN         NaN
# 434          peaches        NaN         NaN
# 435          peaches        NaN         NaN
# 436          peaches        NaN         NaN
# 437          peaches        NaN         NaN
# 438          peaches        NaN         NaN
# 439          peaches        NaN         NaN
# 440          peaches        NaN         NaN
#
# [100 rows x 26 columns]

# %%
path = os.path.join('Cleaned Datasets', 'final-merged.csv')
merged.to_csv(path, index=False)
