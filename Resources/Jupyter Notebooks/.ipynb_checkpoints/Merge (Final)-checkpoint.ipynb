# %%
import numpy as np
import pandas as pd
import os

# %%
#Set the paths
registered_business_path = os.path.join('Cleaned Datasets', 'cleaned_registered_businesses.csv')
health_scores_path = os.path.join('Cleaned Datasets', 'health_scores.csv')

registered_business_df = pd.read_csv(registered_business_path)
health_scores_df = pd.read_csv(health_scores_path)

# %%
registered_business_df.head(10)
len(registered_business_df)
# Out:
# 223102

# %%
#lower the name of the business and street address
registered_business_df['business_name'] = registered_business_df['business_name'].str.lower()
registered_business_df['street_address'] = registered_business_df['street_address'].str.lower()

#Drop any business_name or street_address that has null values
registered_business_df['street_address'].replace('', np.nan, inplace=True)
registered_business_df = registered_business_df.dropna(subset=['street_address'])

#Convert street address column to string 
registered_business_df['street_address'] = registered_business_df['street_address'].astype(str)

registered_business_df.head(1)
len(registered_business_df)
# Out:
# 223098

# %%
#remove the whitespaces at the end of business and street address
registered_business_df['business_name'] = registered_business_df['business_name'].str.strip()
registered_business_df['street_address'] = registered_business_df['street_address'].str.strip()

registered_business_df.head(1)
# Out:
#       location_id ownership_name                 business_name  \
# 0  0376718-03-001   Chan Renee W  blossoming lotus acupuncture
#
#                                 category lic_code         street_address  \
# 0  Private Education and Health Services      NaN  2670 leavenworth st a
#
#   State           City  zipcode business_start_date business_end_date  \
# 0    CA  San Francisco  94109.0          01/28/2010               NaN
#
#   neighborhoods                                 business_location  \
# 0   North Beach  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n
#
#    supervisor_district  Lifespan closed  age_if_opened
# 0                  2.0       NaN     no         3106.0

# %%
registered_business_df.head(1)
# Out:
#       location_id ownership_name                 business_name  \
# 0  0376718-03-001   Chan Renee W  blossoming lotus acupuncture
#
#                                 category lic_code         street_address  \
# 0  Private Education and Health Services      NaN  2670 leavenworth st a
#
#   State           City  zipcode business_start_date business_end_date  \
# 0    CA  San Francisco  94109.0          01/28/2010               NaN
#
#   neighborhoods                                 business_location  \
# 0   North Beach  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n
#
#    supervisor_district  Lifespan closed  age_if_opened
# 0                  2.0       NaN     no         3106.0

# %%
# replace ', ", -, etc
registered_business_df['business_name'] = registered_business_df['business_name'].str.replace(r"[\"\',-.@!$%^&*]", '')

#get the first 2 words from street address
registered_business_df['formatted_address'] = registered_business_df['street_address'].str.split().str[0] + " " + registered_business_df['street_address'].str.split().str[1]
registered_business_df['formatted_name'] = registered_business_df['business_name'].str.split().str[0] + " " + registered_business_df['business_name'].str.split().str[1]

#create a unique id based off the formatted address and name
registered_business_df['uniqueid'] = registered_business_df['formatted_name'] + registered_business_df['formatted_address']


registered_business_df.head(1)
# Out:
#       location_id ownership_name                 business_name  \
# 0  0376718-03-001   Chan Renee W  blossoming lotus acupuncture
#
#                                 category lic_code         street_address  \
# 0  Private Education and Health Services      NaN  2670 leavenworth st a
#
#   State           City  zipcode business_start_date business_end_date  \
# 0    CA  San Francisco  94109.0          01/28/2010               NaN
#
#   neighborhoods                                 business_location  \
# 0   North Beach  2670 LEAVENWORTH ST\nA San Francisco, CA 94109\n
#
#    supervisor_district  Lifespan closed  age_if_opened formatted_address  \
# 0                  2.0       NaN     no         3106.0  2670 leavenworth
#
#      formatted_name                          uniqueid
# 0  blossoming lotus  blossoming lotus2670 leavenworth

# %% [markdown]
# # Clean up the health scores dataset

# %%
health_scores_df.head(10)
# Out:
#    business_id                                name  \
# 0           19               NRGIZE LIFESTYLE CAFE
# 1           19               NRGIZE LIFESTYLE CAFE
# 2           19               NRGIZE LIFESTYLE CAFE
# 3           24  OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 4           24  OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 5           24  OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 6           31      NORMAN'S ICE CREAM AND FREEZES
# 7           31      NORMAN'S ICE CREAM AND FREEZES
# 8           45                 CHARLIE'S DELI CAFE
# 9           45                 CHARLIE'S DELI CAFE
#
#                          address           city state postal_code   latitude  \
# 0   1200 VAN NESS AVE, 3RD FLOOR  San Francisco    CA       94109  37.786848
# 1   1200 VAN NESS AVE, 3RD FLOOR  San Francisco    CA       94109  37.786848
# 2   1200 VAN NESS AVE, 3RD FLOOR  San Francisco    CA       94109  37.786848
# 3  500 CALIFORNIA ST, 2ND  FLOOR  San Francisco    CA       94104  37.792888
# 4  500 CALIFORNIA ST, 2ND  FLOOR  San Francisco    CA       94104  37.792888
# 5  500 CALIFORNIA ST, 2ND  FLOOR  San Francisco    CA       94104  37.792888
# 6           2801 LEAVENWORTH ST   San Francisco    CA       94133  37.807155
# 7           2801 LEAVENWORTH ST   San Francisco    CA       94133  37.807155
# 8                3202 FOLSOM ST   San Francisco    CA       94110  37.747114
# 9                3202 FOLSOM ST   San Francisco    CA       94110  37.747114
#
#     longitude phone_number  score        date     type    year  month
# 0 -122.421547  14157763262   94.0  2017-12-11  routine  2017.0   12.0
# 1 -122.421547  14157763262   96.0  2018-06-07  routine  2018.0    6.0
# 2 -122.421547  14157763262   94.0  2016-05-13  routine  2016.0    5.0
# 3 -122.403135  14156779494   96.0  2016-03-11  routine  2016.0    3.0
# 4 -122.403135  14156779494   98.0  2016-10-05  routine  2016.0   10.0
# 5 -122.403135  14156779494   98.0  2017-11-01  routine  2017.0   11.0
# 6 -122.419004          NaN   98.0  2015-12-04  routine  2015.0   12.0
# 7 -122.419004          NaN   96.0  2018-06-15  routine  2018.0    6.0
# 8 -122.413641  14156415051   85.0  2017-09-14  routine  2017.0    9.0
# 9 -122.413641  14156415051   88.0  2018-05-29  routine  2018.0    5.0

# %%
#lower the name of the business and street address
health_scores_df['name'] = health_scores_df['name'].str.lower()
health_scores_df['address'] = health_scores_df['address'].str.lower()

#Drop any street_address that has null values
health_scores_df['address'].replace('', np.nan, inplace=True)
health_scores_df = health_scores_df.dropna(subset=['address'])

#Convert street address column to string 
health_scores_df['address'] = health_scores_df['address'].astype(str)

registered_business_df.head(1)
len(registered_business_df)
# Out:
# 223098

# %%
#remove the whitespaces at the end of business and street address
health_scores_df['name'] = health_scores_df['name'].str.strip()
health_scores_df['address'] = health_scores_df['address'].str.strip()

health_scores_df.head(1)
# Out:
#    business_id                   name                       address  \
# 0           19  nrgize lifestyle cafe  1200 van ness ave, 3rd floor
#
#             city state postal_code   latitude   longitude phone_number  score  \
# 0  San Francisco    CA       94109  37.786848 -122.421547  14157763262   94.0
#
#          date     type    year  month
# 0  2017-12-11  routine  2017.0   12.0

# %%
# replace ', ", -, etc
health_scores_df['name'] = health_scores_df['name'].str.replace(r"[\"\',-.@!$%^&*]", '')

#get the first 2 words from street address
health_scores_df['formatted_address'] = health_scores_df['address'].str.split().str[0] + " " + health_scores_df['address'].str.split().str[1]
health_scores_df['formatted_name'] = health_scores_df['name'].str.split().str[0] + " " + health_scores_df['name'].str.split().str[1]

#create a unique id based off the formatted address and name
health_scores_df['uniqueid'] = health_scores_df['formatted_name'] + health_scores_df['formatted_address']

#get the columns we need
health_scores_df = health_scores_df[['business_id', 'name', 'score', 'year', 'formatted_address', 'formatted_name', 'latitude', 'longitude', 'uniqueid']]


health_scores_df.head(1)
# Out:
#    business_id                   name  score    year formatted_address  \
# 0           19  nrgize lifestyle cafe   94.0  2017.0          1200 van
#
#      formatted_name   latitude   longitude                  uniqueid
# 0  nrgize lifestyle  37.786848 -122.421547  nrgize lifestyle1200 van

# %%
#Merge the registered business df with the geocodes to get unique location id
merged = registered_business_df.merge(health_scores_df, on=['uniqueid'])

# %%
len(merged)
# Out:
# 24463159

# %%
merged.head(100)
# Out:
#        location_id            ownership_name      business_name  \
# 0   1173752-12-171       Yo-Kai Express Inc.  yokai express inc
# 1   1173814-12-171         Gan Xiang Yu, Llc  sizzling pot king
# 2   1173814-12-171         Gan Xiang Yu, Llc  sizzling pot king
# 3   0015092-01-001              Jug Shop Inc       jug shop inc
# 4   0015092-01-001              Jug Shop Inc       jug shop inc
# 5   0015092-01-001              Jug Shop Inc       jug shop inc
# 6   1037510-08-151               Sweetch Inc           jug shop
# 7   1037510-08-151               Sweetch Inc           jug shop
# 8   1037510-08-151               Sweetch Inc           jug shop
# 9   1122826-10-161            Volans-I, Inc.             runway
# 10  1122826-10-161            Volans-I, Inc.             runway
# 11  1122826-10-161            Volans-I, Inc.             runway
# 12  1122826-10-161            Volans-I, Inc.             runway
# 13  1074581-06-161             Essociate Inc     huntingmooncom
# 14  1074581-06-161             Essociate Inc     huntingmooncom
# 15  1074581-06-161             Essociate Inc     huntingmooncom
# 16  1074581-06-161             Essociate Inc     huntingmooncom
# 17  1177449-01-181              Myways, Inc.           circleof
# 18  1177449-01-181              Myways, Inc.           circleof
# 19  1177449-01-181              Myways, Inc.           circleof
# 20  1177449-01-181              Myways, Inc.           circleof
# 21  1180073-02-181            Retalent, Inc.           retalent
# 22  1180073-02-181            Retalent, Inc.           retalent
# 23  1180073-02-181            Retalent, Inc.           retalent
# 24  1180073-02-181            Retalent, Inc.           retalent
# 25  1188345-05-181                Zensoft.io          zensoftio
# 26  1188345-05-181                Zensoft.io          zensoftio
# 27  1188345-05-181                Zensoft.io          zensoftio
# 28  1188345-05-181                Zensoft.io          zensoftio
# 86                                               NaN
# 87                                               NaN
# 88                                               NaN
# 89                                   Wholesale Trade
# 90                                   Wholesale Trade
# 91                                   Wholesale Trade
# 92                                   Wholesale Trade
# 93                                     Food Services
# 94                                     Food Services
# 95                                     Food Services
# 96                                     Food Services
# 97                                       Information
# 98                                       Information
# 99                                       Information
#
#                          lic_code           street_address State  \
# 0                             NaN      135 4th st ste 4000    CA
# 1   Restaurant 1,000 - 2,000 Sqft               139 8th st    CA
# 2   Restaurant 1,000 - 2,000 Sqft               139 8th st    CA
# 3                        Multiple         1590 pacific ave    CA
# 4                        Multiple         1590 pacific ave    CA
# 5                        Multiple         1590 pacific ave    CA
# 6                             NaN         1590 pacific ave    CA
# 7                             NaN         1590 pacific ave    CA
# 8                             NaN         1590 pacific ave    CA
# 9                             NaN           1355 market st    CA
# 10                            NaN           1355 market st    CA
# 11                            NaN           1355 market st    CA
# 12                            NaN           1355 market st    CA
# 13                            NaN         1355 market st 4    CA
# 14                            NaN         1355 market st 4    CA
# 15                            NaN         1355 market st 4    CA
# 16                            NaN         1355 market st 4    CA
# 17                            NaN      1355 market st #488    CA
# 18                            NaN      1355 market st #488    CA
# 19                            NaN      1355 market st #488    CA
# 20                            NaN      1355 market st #488    CA
# 21                            NaN  1355 market st bldg 488    CA
# 22                            NaN  1355 market st bldg 488    CA
# 23                            NaN  1355 market st bldg 488    CA
# 24                            NaN  1355 market st bldg 488    CA
# 25                            NaN  1355 market st  ste 488    CA
# 26                            NaN  1355 market st  ste 488    CA
# 27                            NaN  1355 market st  ste 488    CA
# 28                            NaN  1355 market st  ste 488    CA
# 29                            NaN   1355 market st 3rd flr    CA
# ..                            ...                      ...   ...
# 70                            NaN           1355 market st    CA
# 71                            NaN           1355 market st    CA
# 72                            NaN           1355 market st    CA
# 73                            NaN       1355 market st 488    CA
# 74                            NaN       1355 market st 488    CA
# 75                            NaN       1355 market st 488    CA
# 76                            NaN       1355 market st 488    CA
# 77                            NaN       1355 market st 488    CA
# 78                            NaN       1355 market st 488    CA
# 79                            NaN       1355 market st 488    CA
# 80                            NaN       1355 market st 488    CA
# 81                            NaN  1355 market st #488 488    CA
# 82                            NaN  1355 market st #488 488    CA
# 83                            NaN  1355 market st #488 488    CA
# 84                            NaN  1355 market st #488 488    CA
# 85                            NaN      1355 market st #488    CA
# 86                            NaN      1355 market st #488    CA
# 87                            NaN      1355 market st #488    CA
# 88                            NaN      1355 market st #488    CA
# 89                            NaN       1355 market st 4th    CA
# 90                            NaN       1355 market st 4th    CA
# 91                            NaN       1355 market st 4th    CA
# 92                            NaN       1355 market st 4th    CA
# 93         Take-Out Establishment           1355 market st    CA
# 94         Take-Out Establishment           1355 market st    CA
# 95         Take-Out Establishment           1355 market st    CA
# 96         Take-Out Establishment           1355 market st    CA
# 97                            NaN      1355 market st #488    CA
# 98                            NaN      1355 market st #488    CA
# 99                            NaN      1355 market st #488    CA
#
#              City  zipcode business_start_date     ...     closed  \
# 0   San Francisco  94103.0          12/28/2017     ...         no
# 97  San Francisco  94103.0          06/15/2015     ...        yes
# 98  San Francisco  94103.0          06/15/2015     ...        yes
# 99  San Francisco  94103.0          06/15/2015     ...        yes
#
#    age_if_opened formatted_address  formatted_name  business_id  \
# 0          215.0           135 4th   yokai express        94310
# 1          215.0           139 8th    sizzling pot        94408
# 2          215.0           139 8th    sizzling pot        94408
# 3        18200.0      1590 pacific        jug shop        23704
# 4        18200.0      1590 pacific        jug shop        23704
# 5        18200.0      1590 pacific        jug shop        23704
# 6            NaN      1590 pacific        jug shop        23704
# 7            NaN      1590 pacific        jug shop        23704
# 8            NaN      1590 pacific        jug shop        23704
# 9          943.0       1355 market             NaN        80659
# 10         943.0       1355 market             NaN        80659
# 11         943.0       1355 market             NaN        80659
# 12         943.0       1355 market             NaN        80659
# 13        6420.0       1355 market             NaN        80659
# 14        6420.0       1355 market             NaN        80659
# 15        6420.0       1355 market             NaN        80659
# 16        6420.0       1355 market             NaN        80659
# 17         242.0       1355 market             NaN        80659
# 18         242.0       1355 market             NaN        80659
# 19         242.0       1355 market             NaN        80659
# 20         242.0       1355 market             NaN        80659
# 21         293.0       1355 market             NaN        80659
# 22         293.0       1355 market             NaN        80659
# 23         293.0       1355 market             NaN        80659
# 24         293.0       1355 market             NaN        80659
# 25         760.0       1355 market             NaN        80659
# 26         760.0       1355 market             NaN        80659
# 27         760.0       1355 market             NaN        80659
# 28         760.0       1355 market             NaN        80659
# 29           NaN       1355 market             NaN        80659
# ..           ...               ...             ...          ...
# 70        1828.0       1355 market             NaN        80659
# 71        1828.0       1355 market             NaN        80659
# 72        1828.0       1355 market             NaN        80659
# 73        1978.0       1355 market             NaN        80659
# 74        1978.0       1355 market             NaN        80659
# 75        1978.0       1355 market             NaN        80659
# 76        1978.0       1355 market             NaN        80659
# 77        1579.0       1355 market             NaN        80659
# 78        1579.0       1355 market             NaN        80659
# 79        1579.0       1355 market             NaN        80659
# 80        1579.0       1355 market             NaN        80659
# 81        1548.0       1355 market             NaN        80659
# 82        1548.0       1355 market             NaN        80659
# 83        1548.0       1355 market             NaN        80659
# 84        1548.0       1355 market             NaN        80659
# 85           NaN       1355 market             NaN        80659
# 86           NaN       1355 market             NaN        80659
# 87           NaN       1355 market             NaN        80659
# 88           NaN       1355 market             NaN        80659
# 89           NaN       1355 market             NaN        80659
# 90           NaN       1355 market             NaN        80659
# 91           NaN       1355 market             NaN        80659
# 92           NaN       1355 market             NaN        80659
# 93        1401.0       1355 market             NaN        80659
# 94        1401.0       1355 market             NaN        80659
# 95        1401.0       1355 market             NaN        80659
# 96        1401.0       1355 market             NaN        80659
# 97           NaN       1355 market             NaN        80659
# 98           NaN       1355 market             NaN        80659
# 99           NaN       1355 market             NaN        80659
#
#                  name  score    year  latitude   longitude
# 0       yokai express  100.0  2018.0       NaN         NaN
# 1   sizzling pot king   86.0  2018.0       NaN         NaN
# 2   sizzling pot king   80.0  2018.0       NaN         NaN
# 3        jug shop inc   92.0  2017.0  37.79511 -122.421411
# 4        jug shop inc   90.0  2016.0  37.79511 -122.421411
# 5        jug shop inc   96.0  2016.0  37.79511 -122.421411
# 6        jug shop inc   92.0  2017.0  37.79511 -122.421411
# 7        jug shop inc   90.0  2016.0  37.79511 -122.421411
# 8        jug shop inc   96.0  2016.0  37.79511 -122.421411
# 9            azalinas   91.0  2018.0       NaN         NaN
# 10           azalinas   83.0  2016.0       NaN         NaN
# 11           azalinas   94.0  2017.0       NaN         NaN
# 12           azalinas   92.0  2017.0       NaN         NaN
# 13           azalinas   91.0  2018.0       NaN         NaN
# 14           azalinas   83.0  2016.0       NaN         NaN
# 15           azalinas   94.0  2017.0       NaN         NaN
# 16           azalinas   92.0  2017.0       NaN         NaN
# 17           azalinas   91.0  2018.0       NaN         NaN
# 18           azalinas   83.0  2016.0       NaN         NaN
# 19           azalinas   94.0  2017.0       NaN         NaN
# 20           azalinas   92.0  2017.0       NaN         NaN
# 21           azalinas   91.0  2018.0       NaN         NaN
# 22           azalinas   83.0  2016.0       NaN         NaN
# 23           azalinas   94.0  2017.0       NaN         NaN
# 24           azalinas   92.0  2017.0       NaN         NaN
# 25           azalinas   91.0  2018.0       NaN         NaN
# 26           azalinas   83.0  2016.0       NaN         NaN
# 27           azalinas   94.0  2017.0       NaN         NaN
# 28           azalinas   92.0  2017.0       NaN         NaN
# 29           azalinas   91.0  2018.0       NaN         NaN
# ..                ...    ...     ...       ...         ...
# 70           azalinas   83.0  2016.0       NaN         NaN
# 71           azalinas   94.0  2017.0       NaN         NaN
# 72           azalinas   92.0  2017.0       NaN         NaN
# 73           azalinas   91.0  2018.0       NaN         NaN
# 74           azalinas   83.0  2016.0       NaN         NaN
# 75           azalinas   94.0  2017.0       NaN         NaN
# 76           azalinas   92.0  2017.0       NaN         NaN
# 77           azalinas   91.0  2018.0       NaN         NaN
# 78           azalinas   83.0  2016.0       NaN         NaN
# 79           azalinas   94.0  2017.0       NaN         NaN
# 80           azalinas   92.0  2017.0       NaN         NaN
# 81           azalinas   91.0  2018.0       NaN         NaN
# 82           azalinas   83.0  2016.0       NaN         NaN
# 83           azalinas   94.0  2017.0       NaN         NaN
# 84           azalinas   92.0  2017.0       NaN         NaN
# 85           azalinas   91.0  2018.0       NaN         NaN
# 86           azalinas   83.0  2016.0       NaN         NaN
# 87           azalinas   94.0  2017.0       NaN         NaN
# 88           azalinas   92.0  2017.0       NaN         NaN
# 89           azalinas   91.0  2018.0       NaN         NaN
# 90           azalinas   83.0  2016.0       NaN         NaN
# 91           azalinas   94.0  2017.0       NaN         NaN
# 92           azalinas   92.0  2017.0       NaN         NaN
# 93           azalinas   91.0  2018.0       NaN         NaN
# 94           azalinas   83.0  2016.0       NaN         NaN
# 95           azalinas   94.0  2017.0       NaN         NaN
# 96           azalinas   92.0  2017.0       NaN         NaN
# 97           azalinas   91.0  2018.0       NaN         NaN
# 98           azalinas   83.0  2016.0       NaN         NaN
# 99           azalinas   94.0  2017.0       NaN         NaN
#
# [100 rows x 25 columns]

# %%
path = os.path.join('Cleaned Datasets', 'final-merged.csv')
merged.to_csv(path, index=False)
