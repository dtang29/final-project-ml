{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 7    [{'alias': 'french', 'title': 'French'}, {'ali...
# 8    [{'alias': 'newamerican', 'title': 'American (...
# 9    [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 10   [{'alias': 'newamerican', 'title': 'American (...
# 11              [{'alias': 'ramen', 'title': 'Ramen'}]
# 12   [{'alias': 'latin', 'title': 'Latin American'}...
# 13   [{'alias': 'caribbean', 'title': 'Caribbean'},...
# 14   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 15              [{'alias': 'pizza', 'title': 'Pizza'}]
# 16   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 17   [{'alias': 'vietnamese', 'title': 'Vietnamese'...
# 18   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 19   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 20   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...
# 21   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 22   [{'alias': 'french', 'title': 'French'}, {'ali...
# 23          [{'alias': 'mexican', 'title': 'Mexican'}]
# 24   [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 25          [{'alias': 'burmese', 'title': 'Burmese'}]
# 26   [{'alias': 'grocery', 'title': 'Grocery'}, {'a...
# 27   [{'alias': 'tradamerican', 'title': 'American ...
# 28   [{'alias': 'foodtrucks', 'title': 'Food Trucks...
# 29   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# ..                                                 ...
# 920         [{'alias': 'mexican', 'title': 'Mexican'}]
# 921  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...
# 922  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 923  [{'alias': 'tradamerican', 'title': 'American ...
# 924         [{'alias': 'italian', 'title': 'Italian'}]
# 925  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 926           [{'alias': 'french', 'title': 'French'}]
# 927  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...
# 928  [{'alias': 'latin', 'title': 'Latin American'}...
# 929  [{'alias': 'newamerican', 'title': 'American (...
# 930  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 931  [{'alias': 'tradamerican', 'title': 'American ...
# 932  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 933         [{'alias': 'italian', 'title': 'Italian'}]
# 934  [{'alias': 'breakfast_brunch', 'title': 'Break...
# 935         [{'alias': 'italian', 'title': 'Italian'}]
# 936  [{'alias': 'spanish', 'title': 'Spanish'}, {'a...
# 937  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 938  [{'alias': 'newamerican', 'title': 'American (...
# 939  [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 940  [{'alias': 'steak', 'title': 'Steakhouses'}, {...
# 941  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 942  [{'alias': 'hawaiian', 'title': 'Hawaiian'}, {...
# 943  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 944         [{'alias': 'chinese', 'title': 'Chinese'}]
# 945  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 946  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 947  [{'alias': 'delis', 'title': 'Delis'}, {'alias...
# 948  [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 949         [{'alias': 'mexican', 'title': 'Mexican'}]
#
#                                            coordinates   display_phone  \
# 0    {'latitude': 37.768314, 'longitude': -122.421642}  (415) 678-5767
# 1    {'latitude': 37.808944, 'longitude': -122.418462}  (415) 771-4383
# 2      {'latitude': 37.78326, 'longitude': -122.46283}  (415) 379-6414
# 3    {'latitude': 37.7756673618778, 'longitude': -1...  (415) 409-0679
# 4    {'latitude': 37.7614143, 'longitude': -122.424...  (415) 437-6800
# 5    {'latitude': 37.787823, 'longitude': -122.413699}  (415) 409-6120
# 941  https://s3-media4.fl.yelpcdn.com/bphoto/z-5Fyy...      False
# 942  https://s3-media2.fl.yelpcdn.com/bphoto/FF7NuQ...      False
# 943  https://s3-media1.fl.yelpcdn.com/bphoto/2vQmib...      False
# 944  https://s3-media1.fl.yelpcdn.com/bphoto/Dhhxbg...      False
# 945  https://s3-media1.fl.yelpcdn.com/bphoto/aNOdUN...      False
# 946  https://s3-media4.fl.yelpcdn.com/bphoto/6c-h6x...      False
# 947  https://s3-media3.fl.yelpcdn.com/bphoto/sPZvQW...      False
# 948  https://s3-media3.fl.yelpcdn.com/bphoto/UpqqAW...      False
# 949  https://s3-media1.fl.yelpcdn.com/bphoto/HBua6f...      False
#
#                                               location  \
# 0    {'address1': '370 14th St', 'address2': '', 'a...
# 1    {'address1': '1965 Al Scoma Way', 'address2': ...
# 2    {'address1': '330 Clement St', 'address2': '',...
# 3    {'address1': '655 Divisadero St', 'address2': ...
# 4    {'address1': '3611 18th St', 'address2': None,...
# 5    {'address1': '708 Post St', 'address2': None, ...
# 6    {'address1': '826 Folsom St', 'address2': '', ...
# 7    {'address1': '2316 Polk St', 'address2': '', '...
# 8    {'address1': '500 Brannan St', 'address2': '',...
# 9    {'address1': '1039 Stockton St', 'address2': '...
# 10   {'address1': '1 Mission St', 'address2': '', '...
# 11   {'address1': '1581 Webster St', 'address2': 'S...
# 12   {'address1': 'Pier 1 1/2 The Embarcadero', 'ad...
# 13   {'address1': '1801 Haight St', 'address2': '',...
# 14   {'address1': '809 Bush St', 'address2': '', 'a...
# 15   {'address1': '400 Valencia St', 'address2': No...
# 16   {'address1': '721 Market St', 'address2': '', ...
# 17   {'address1': '1 Ferry Bldg', 'address2': 'Ste ...
# 18   {'address1': '730 Larkin St', 'address2': '', ...
# 19   {'address1': '4101 Judah St', 'address2': '', ...
# 20   {'address1': '631 Kearny St', 'address2': '', ...
# 21   {'address1': '1914 Fillmore St', 'address2': '...
# 22   {'address1': '3324 Steiner St', 'address2': ''...
# 23   {'address1': '510 Union St', 'address2': '', '...
# 24   {'address1': '1 Ferry Bldg', 'address2': '', '...
# 25   {'address1': '4348 California St', 'address2':...
# 26   {'address1': '1901 San Jose Ave', 'address2': ...
# 27   {'address1': '3640 Sacramento St', 'address2':...
# 28   {'address1': '670 Larkin Ste', 'address2': '',...
# 29   {'address1': '475 3rd St', 'address2': '', 'ad...
# ..                                                 ...
# 920  {'address1': '425 Hayes St', 'address2': 'Ste ...
# 921  {'address1': 'Pier 33 N The Embarcadero', 'add...
# 922  {'address1': '98 Mission St', 'address2': '', ...
# 923  {'address1': '1428 Haight St', 'address2': '',...
# 924  {'address1': '129 Ellis St', 'address2': '', '...
# 925  {'address1': '5423 Geary Blvd', 'address2': ''...
# 926  {'address1': '1521 Hyde St', 'address2': '', '...
# 927  {'address1': '3132 Vicente St', 'address2': ''...
# 928  {'address1': '3126 24th St', 'address2': '', '...
# 929  {'address1': '1796 Union St', 'address2': '', ...
# 930  {'address1': '3801 Mission St', 'address2': ''...
# 931  {'address1': '801 Mission St', 'address2': '',...
# 932  {'address1': '2030 Union St', 'address2': None...
# 933  {'address1': '3230 Mission St', 'address2': ''...
# 934  {'address1': 'Pier 30', 'address2': '', 'addre...
# 935  {'address1': '1270 Valencia St', 'address2': '...
# 936  {'address1': '44 Belden Pl', 'address2': '', '...
# 937  {'address1': '740 Market St', 'address2': '', ...
# 938  {'address1': '300 Precita Ave', 'address2': No...
# 939  {'address1': '1161 Post St', 'address2': '', '...
# 940  {'address1': '400 Post St', 'address2': '', 'a...
# 941  {'address1': '149 New Montgomery St', 'address...
# 942  {'address1': '1865 Post St', 'address2': '', '...
# 943  {'address1': '6314 Geary Blvd', 'address2': ''...
# 944  {'address1': '839 Clay St', 'address2': '', 'a...
# 945  {'address1': '3435 Mission St', 'address2': ''...
# 946  {'address1': '2170 Mission St', 'address2': ''...
# 947  {'address1': '2115 Irving St', 'address2': '',...
# 948  {'address1': '1269 9th Ave', 'address2': '', '...
# 949  {'address1': '598 Valencia St', 'address2': No...
#
#                                  name         phone price  rating  \
# 0    Shizen Vegan Sushi Bar & Izakaya  1.415679e+10    $$     4.5
# 1                  Scoma's Restaurant  1.415771e+10   $$$     4.0
# 2            Genki Crepes & Mini-Mart  1.415380e+10     $     4.0
# 3                           Bar Crudo  1.415409e+10   $$$     4.0
# 4    Pizzeria Delfina - San Francisco  1.415438e+10    $$     4.0
# 5              Pearl's Deluxe Burgers  1.415410e+10    $$     4.0
# 6                           Zero Zero  1.415349e+10    $$     4.0
# 7                            La Folie  1.415777e+10  $$$$     4.5
# 8                             Marlowe  1.415777e+10    $$     4.0
# 9                Good Mong Kok Bakery  1.415397e+10     $     4.0
# 10                          Boulevard  1.415544e+10  $$$$     4.0
# 11                     Marufuku Ramen  1.415873e+10    $$     4.5
# 12          La Mar Cebichería Peruana  1.415398e+10   $$$     4.0
# 13                        Cha Cha Cha  1.415387e+10    $$     4.0
# 14                            Tacorea  1.415885e+10     $     4.5
# 15                  Little Star Pizza  1.415552e+10    $$     4.0
# 16                Super Duper Burgers  1.415538e+10    $$     4.0
# 17                   The Slanted Door  1.415862e+10   $$$     3.5
# 18                           Lers Ros  1.415932e+10    $$     4.0
# 19                         Thanh Long  1.415665e+10   $$$     4.0
# 20                         R&G Lounge  1.415983e+10    $$     3.5
# 21             Woodhouse Fish Company  1.415437e+10    $$     4.0
# 22                     Isa Restaurant  1.415568e+10   $$$     4.0
# 23                        Don Pisto's  1.415395e+10    $$     4.0
# 24       Roli Roti Gourmet Rotisserie  1.510780e+10     $     4.5
# 25                           Mandalay  1.415386e+10    $$     4.0
# 26                  Roxie Food Center  1.415587e+10     $     4.5
# 27                             Spruce  1.415932e+10  $$$$     4.0
# 28                 The Chairman Truck  1.415814e+10     $     4.0
# 29                             Garaje  1.415644e+10    $$     4.5
# ..                                ...           ...   ...     ...
# 920                      Papito Hayes  1.415554e+10    $$     4.0
# 921     Queen's Louisiana Po-Boy Cafe  1.415397e+10    $$     4.0
# 922               Super Duper Burgers  1.415974e+10    $$     4.0
# 923  1428 HAIGHT Patio Cafe & Crepery  1.415865e+10    $$     4.0
# 924                 Puccini & Pinetti  1.415393e+10    $$     3.5
# 925                             Swamp  1.415876e+10    $$     3.5
# 926                           Cocotte  1.415292e+10   $$$     4.0
# 927   Old Mandarin Islamic Restaurant  1.415564e+10    $$     3.5
# 928               Sun Rise Restaurant  1.415206e+10     $     4.0
# 929                         Lite Bite  1.415932e+10    $$     4.5
# 930                Balompie Cafe No 3  1.415647e+10     $     4.0
# 931                    Mel's Drive-In  1.415227e+10    $$     3.0
# 932                            Flores  1.415796e+10    $$     4.0
# 933            Emmy's Spaghetti Shack  1.415206e+10    $$     4.0
# 934                  Red's Java House  1.415778e+10     $     3.5
# 935                          BARZOTTO  1.415285e+10    $$     4.0
# 936                B44 Catalan Bistro  1.415987e+10   $$$     3.5
# 937                        Cafe Dolci  1.415393e+10     $     4.0
# 938              Hillside Supper Club  1.415286e+10    $$     4.0
# 939                           YamaSho  1.415346e+10    $$     3.5
# 940           Morton's The Steakhouse  1.415987e+10  $$$$     3.5
# 941                    Cafe Madeleine  1.415227e+10     $     4.0
# 942        Pa'ina Lounge & Restaurant  1.415829e+10    $$     4.0
# 943                      Jang Soo BBQ  1.415222e+10    $$     4.0
# 944                Capital Restaurant  1.415398e+10     $     3.5
# 945                     El Buen Comer  1.415817e+10    $$     4.0
# 946                      Southpaw BBQ  1.415935e+10    $$     3.5
# 947                      Sunrise Deli  1.415665e+10     $     4.0
# 948          Kiki Japanese Restaurant  1.415662e+10     $     3.5
# 949                  El Toro Taqueria  1.415431e+10     $     3.5
#
#      review_count                                      transactions  \
# 0            1118                        ['restaurant_reservation']
# 1            3129                        ['restaurant_reservation']
# 2            2112                                                []
# 3            1771                                                []
# 4            2199                                                []
# 5            2012                                                []
# 6            2970                        ['restaurant_reservation']
# 7            1400                                                []
# 8            2451                                                []
# 9            2092                                                []
# 10           2491                                                []
# 11           1338                                                []
# 12           3329                                                []
# 13           3030                                                []
# 14           1165                                                []
# 15           1923              ['restaurant_reservation', 'pickup']
# 16           2493                                                []
# 17           5227                                                []
# 18           2053                                      ['delivery']
# 19           2305                        ['restaurant_reservation']
# 20           4017                                                []
# 21           2029                                                []
# 22           1904              ['restaurant_reservation', 'pickup']
# 23           1675                                                []
# 24           1367                                                []
# 25           1937                        ['restaurant_reservation']
# 26            925                            ['delivery', 'pickup']
# 27           1753                                                []
# 28           1381                                                []
# 29           1367                                                []
# ..            ...                                               ...
# 920           452                                                []
# 921           512                                        ['pickup']
# 922           444                                                []
# 923           295                            ['delivery', 'pickup']
# 924           979                            ['delivery', 'pickup']
# 925           578                            ['delivery', 'pickup']
# 926           456              ['restaurant_reservation', 'pickup']
# 927           732                                        ['pickup']
# 928           322                                                []
# 929           256                            ['delivery', 'pickup']
# 930           297                                        ['pickup']
# 931          1821                            ['delivery', 'pickup']
# 932           311                                                []
# 933           370              ['restaurant_reservation', 'pickup']
# 934           752                                                []
# 935           367                            ['delivery', 'pickup']
# 936           984  ['delivery', 'restaurant_reservation', 'pickup']
# 937           414                                                []
# 938           324  ['delivery', 'restaurant_reservation', 'pickup']
# 939           550                        ['restaurant_reservation']
# 940          1092                                                []
# 941           434                                                []
# 942           447  ['delivery', 'restaurant_reservation', 'pickup']
# 943           469                                        ['pickup']
# 944           589                            ['delivery', 'pickup']
# 945           222              ['restaurant_reservation', 'pickup']
# 946           547  ['delivery', 'restaurant_reservation', 'pickup']
# 947           494                                        ['pickup']
# 948           895                            ['delivery', 'pickup']
# 949           614                            ['delivery', 'pickup']
#
#                                                    url
# 0    https://www.yelp.com/biz/shizen-vegan-sushi-ba...
# 1    https://www.yelp.com/biz/scomas-restaurant-san...
# 2    https://www.yelp.com/biz/genki-crepes-and-mini...
# 3    https://www.yelp.com/biz/bar-crudo-san-francis...
# 4    https://www.yelp.com/biz/pizzeria-delfina-san-...
# 5    https://www.yelp.com/biz/pearls-deluxe-burgers...
# 6    https://www.yelp.com/biz/zero-zero-san-francis...
# 7    https://www.yelp.com/biz/la-folie-san-francisc...
# 8    https://www.yelp.com/biz/marlowe-san-francisco...
# 9    https://www.yelp.com/biz/good-mong-kok-bakery-...
# 10   https://www.yelp.com/biz/boulevard-san-francis...
# 11   https://www.yelp.com/biz/marufuku-ramen-san-fr...
# 12   https://www.yelp.com/biz/la-mar-cebicher%C3%AD...
# 13   https://www.yelp.com/biz/cha-cha-cha-san-franc...
# 14   https://www.yelp.com/biz/tacorea-san-francisco...
# 15   https://www.yelp.com/biz/little-star-pizza-san...
# 16   https://www.yelp.com/biz/super-duper-burgers-s...
# 17   https://www.yelp.com/biz/the-slanted-door-san-...
# 18   https://www.yelp.com/biz/lers-ros-san-francisc...
# 19   https://www.yelp.com/biz/thanh-long-san-franci...
# 20   https://www.yelp.com/biz/r-and-g-lounge-san-fr...
# 21   https://www.yelp.com/biz/woodhouse-fish-compan...
# 22   https://www.yelp.com/biz/isa-restaurant-san-fr...
# 23   https://www.yelp.com/biz/don-pistos-san-franci...
# 24   https://www.yelp.com/biz/roli-roti-gourmet-rot...
# 25   https://www.yelp.com/biz/mandalay-san-francisc...
# 26   https://www.yelp.com/biz/roxie-food-center-san...
# 27   https://www.yelp.com/biz/spruce-san-francisco?...
# 28   https://www.yelp.com/biz/the-chairman-truck-sa...
# 29   https://www.yelp.com/biz/garaje-san-francisco?...
# ..                                                 ...
# 920  https://www.yelp.com/biz/papito-hayes-san-fran...
# 921  https://www.yelp.com/biz/queens-louisiana-po-b...
# 922  https://www.yelp.com/biz/super-duper-burgers-s...
# 923  https://www.yelp.com/biz/1428-haight-patio-caf...
# 924  https://www.yelp.com/biz/puccini-and-pinetti-s...
# 925  https://www.yelp.com/biz/swamp-san-francisco?a...
# 926  https://www.yelp.com/biz/cocotte-san-francisco...
# 927  https://www.yelp.com/biz/old-mandarin-islamic-...
# 928  https://www.yelp.com/biz/sun-rise-restaurant-s...
# 929  https://www.yelp.com/biz/lite-bite-san-francis...
# 930  https://www.yelp.com/biz/balompie-cafe-no-3-sa...
# 931  https://www.yelp.com/biz/mels-drive-in-san-fra...
# 932  https://www.yelp.com/biz/flores-san-francisco?...
# 933  https://www.yelp.com/biz/emmys-spaghetti-shack...
# 934  https://www.yelp.com/biz/reds-java-house-san-f...
# 935  https://www.yelp.com/biz/barzotto-san-francisc...
# 936  https://www.yelp.com/biz/b44-catalan-bistro-sa...
# 937  https://www.yelp.com/biz/cafe-dolci-san-franci...
# 938  https://www.yelp.com/biz/hillside-supper-club-...
# 939  https://www.yelp.com/biz/yamasho-san-francisco...
# 940  https://www.yelp.com/biz/mortons-the-steakhous...
# 941  https://www.yelp.com/biz/cafe-madeleine-san-fr...
# 942  https://www.yelp.com/biz/paina-lounge-and-rest...
# 943  https://www.yelp.com/biz/jang-soo-bbq-san-fran...
# 944  https://www.yelp.com/biz/capital-restaurant-sa...
# 945  https://www.yelp.com/biz/el-buen-comer-san-fra...
# 946  https://www.yelp.com/biz/southpaw-bbq-san-fran...
# 947  https://www.yelp.com/biz/sunrise-deli-san-fran...
# 948  https://www.yelp.com/biz/kiki-japanese-restaur...
# 949  https://www.yelp.com/biz/el-toro-taqueria-san-...
#
# [950 rows x 16 columns]

# %%
# https://learn.co/lessons/python-api-intro-yelp
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from pprint import pprint
from config import api_key1


url = 'https://api.yelp.com/v3/businesses/search'
headers = {
        'Authorization': 'Bearer {}'.format(api_key1),
    }
print("Parameter reference:" + " " + "https://www.yelp.com/developers/documentation/v3/business_search")
url_params = {
                "categories": 'restaurants, All',
                "location":"San Francisco",
                "state": "California",
                "limit":50
            }
response = requests.get(url, headers=headers, params=url_params)
print(response)

response_json = response.json()
pprint(response_json)

# Returns 59 locations for category: Food > bagels
    # Returns 6,200 locations for category: Bagels
    
# Returns 545 locations for category: Grocery > grocery, All
# Out:
# Parameter reference: https://www.yelp.com/developers/documentation/v3/business_search
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-0ebc3118467e> in <module>()
#      20                 "limit":50
#      21             }
# ---> 22 response = requests.get(url, headers=headers, params=url_params)
#      23 print(response)
#      24
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\urllib3\connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      58     family = allowed_gai_family()
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#      62         sock = None
#
# ~\AppData\Local\conda\conda\envs\FinalProject\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     743     # and socket type values to enum constants.
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#     747         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
print("API documentation >>> " + " " + "https://www.yelp.com/developers/documentation/v3/all_category_list")
response.json().keys()
df = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(df)) #Print how many rows
print(df.columns) #Print column names
df.head() #Previews the first five row
# Out:
# API documentation >>>  https://www.yelp.com/developers/documentation/v3/all_category_list
# 50
# Index(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
#        'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
#        'rating', 'review_count', 'transactions', 'url'],
#       dtype='object')
#                                     alias  \
# 0  brendas-french-soul-food-san-francisco
# 1                gary-danko-san-francisco
# 2   tartine-bakery-and-cafe-san-francisco
# 3        house-of-prime-rib-san-francisco
# 4      hog-island-oyster-co-san-francisco
#
#                                           categories  \
# 0  [{'alias': 'breakfast_brunch', 'title': 'Break...
# 1  [{'alias': 'newamerican', 'title': 'American (...
# 2  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 3  [{'alias': 'tradamerican', 'title': 'American ...
# 4  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 37.7829016035273, 'longitude': -1...  (415) 345-8100
# 1    {'latitude': 37.80587, 'longitude': -122.42058}  (415) 749-2060
# 2  {'latitude': 37.7614250022004, 'longitude': -1...  (415) 487-2600
# 3     {'latitude': 37.79338, 'longitude': -122.4225}  (415) 885-4605
# 4  {'latitude': 37.795831, 'longitude': -122.393303}  (415) 391-7117
#
#       distance                      id  \
# 0  2885.389131  lJAGnYzku5zSaLnQ_T6_GQ
# 1  5191.341803  WavvLdfdP6g8aZTtbBQHTw
# 2  1091.249586  ri7UUYmx21AgSpRsf4-9QA
# 3  3819.642258  oT08T3Vpn1I7jDmrBBRMTw
# 4  5428.156707  Xg-FyjVKAN70LO4u4Z1ozg
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/YT8ho0...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/NCX50S...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/vTLu8G...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/HLrjaM...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/sSxges...      False
#
#                                             location  \
# 0  {'address1': '652 Polk St', 'address2': '', 'a...
# 1  {'address1': '800 N Point St', 'address2': '',...
# 2  {'address1': '600 Guerrero St', 'address2': ''...
# 3  {'address1': '1906 Van Ness Ave', 'address2': ...
# 4  {'address1': '1 Ferry Bldg', 'address2': '', '...
#
#                         name         phone price  rating  review_count  \
# 0  Brenda's French Soul Food  +14153458100    $$     4.0          9393
# 1                 Gary Danko  +14157492060  $$$$     4.5          4834
# 2      Tartine Bakery & Cafe  +14154872600    $$     4.0          7241
# 3         House of Prime Rib  +14158854605   $$$     4.0          6383
# 4       Hog Island Oyster Co  +14153917117    $$     4.5          5169
#
#   transactions                                                url
# 0           []  https://www.yelp.com/biz/brendas-french-soul-f...
# 1           []  https://www.yelp.com/biz/gary-danko-san-franci...
# 2           []  https://www.yelp.com/biz/tartine-bakery-and-ca...
# 3           []  https://www.yelp.com/biz/house-of-prime-rib-sa...
# 4           []  https://www.yelp.com/biz/hog-island-oyster-co-...

# %%
#Save as csv
df.to_csv("data/yelp_grocery.csv",index=False)
yelp_grocery = "data/yelp_grocery.csv"
yelp_df = pd.read_csv(yelp_grocery)
yelp_df.head()

# %%
import folium

lat_long = response.json()['region']['center']
lat = lat_long['latitude']
long = lat_long['longitude']

#Create a map of the area
yelp_map = folium.Map([lat, long])
yelp_map

folium.Marker?

for row in df.index:
    lat_long = df['coordinates'][row]
    lat = lat_long['latitude']
    long = lat_long['longitude']
    name = df['name'][row]
    rating = df['rating'][row]
    price = df['price'][row]
    details = '{} Price: {} Rating:{}'.format(name,price,rating)
    marker = folium.Marker([lat, long])
    marker.add_to(yelp_map)
yelp_map

# %%
######################################### Testing ###############################################################

# %%
# https://learn.co/lessons/python-api-intro-yelp
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from pprint import pprint
from config import api_key1


def query_api(offset):
    url = 'https://api.yelp.com/v3/businesses/search'
    response_json = []
    headers = {
            'Authorization': 'Bearer {}'.format(api_key1),
        }

    url_params = {
                    "categories": 'grocery, All',
                    "location":"San Francisco",
                    "state": "California",
                    "limit":50,
                    "offset": offset
                }

    response = requests.get(url, headers=headers, params=url_params)
    response_json = response.json()
    print(response)

    for location in response.json()['businesses']:
            response.json()['businesses'].append(location)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
response.json().keys()
df = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(df)) #Print how many rows
print(df.columns) #Print column names
df.head()
# Out:
# 50
# Index(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
#        'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
#        'rating', 'review_count', 'transactions', 'url'],
#       dtype='object')
#                                     alias  \
# 0  italian-homemade-company-san-francisco
# 1            bi-rite-market-san-francisco
# 2          lucca-ravioli-co-san-francisco
# 3      haight-street-market-san-francisco
# 4          bi-rite-market-san-francisco-3
#
#                                           categories  \
# 0  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...
# 1  [{'alias': 'gourmet', 'title': 'Specialty Food...
# 2         [{'alias': 'grocery', 'title': 'Grocery'}]
# 3  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...
# 4         [{'alias': 'grocery', 'title': 'Grocery'}]
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 37.801752, 'longitude': -122.411851}  (415) 712-8874
# 1  {'latitude': 37.7613794289775, 'longitude': -1...  (415) 241-9760
# 2  {'latitude': 37.7552178, 'longitude': -122.421...  (415) 647-5581
# 3    {'latitude': 37.77021, 'longitude': -122.44758}  (415) 255-0643
# 4  {'latitude': 37.7745126368117, 'longitude': -1...  (415) 551-7900
#
#       distance                      id  \
# 0  5030.673144  K9XVDlPNhrrSVEJN7uWqJQ
# 1  1034.658099  H3LVKSUbbUFqlTuxDKerAg
# 2  1481.464675  AH2lEHfc0nX42ACnjBm__g
# 3  1425.844358  Yi37TP021npWZsOPeZ2Xqw
# 4  1516.905665  sPUkCbbBBuEa5bSQE3BR-A
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/PHnJ_t...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/lrTjUH...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/DtIuXo...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/MmURdA...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/x7k8IW...      False
#
#                                             location  \
# 0  {'address1': '716 Columbus Ave', 'address2': '...
# 1  {'address1': '3639 18th St', 'address2': '', '...
# 2  {'address1': '1100 Valencia St', 'address2': '...
# 3  {'address1': '1530 Haight St', 'address2': '',...
# 4  {'address1': '550 Divisadero St', 'address2': ...
#
#                        name         phone price  rating  review_count  \
# 0  Italian Homemade Company  +14157128874    $$     4.5          1069
# 1            Bi-Rite Market  +14152419760   $$$     4.5           886
# 2          Lucca Ravioli Co  +14156475581    $$     4.5           477
# 3      Haight Street Market  +14152550643    $$     4.5           442
# 4            Bi-Rite Market  +14155517900    $$     4.5           440
#
#          transactions                                                url
# 0  [delivery, pickup]  https://www.yelp.com/biz/italian-homemade-comp...
# 1                  []  https://www.yelp.com/biz/bi-rite-market-san-fr...
# 2                  []  https://www.yelp.com/biz/lucca-ravioli-co-san-...
# 3                  []  https://www.yelp.com/biz/haight-street-market-...
# 4                  []  https://www.yelp.com/biz/bi-rite-market-san-fr...

# %%
######################################### Google Places API ###############################################################

# %%
# https://www.geeksforgeeks.org/python-get-set-places-according-search-query-using-google-places-api/
from config import api_key2

api_key = api_key2
url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?'

query = input('Search query: ')
response = requests.get(url + 'query=' + query +
                        '&key=' + api_key)

print(response)
 
# json method of response object convert
#  json format data into python format data
response_json = response.json()
pprint(response_json)

# now x contains list of nested dictionaries
# we know dictionary contain key value pair
# store the value of result key in variable y
y = x['results']
 
# keep looping upto lenght of y
for i in range(len(y)):
     
    # Print value corresponding to the
    # 'name' key at the ith index of y
    print(y[i]['name'])

# %%
response.json().keys()

# %%
df = pd.DataFrame.from_dict(response.json()['results'])
print(len(df)) #Print how many rows
print(df.columns) #Print column names
df.head() #Previews the first five row

# %%
######################################### Open Data SF ###############################################################

# %%
RBL_df =pd.read_csv("data/Registered_Business_Locations.csv")

print(list(RBL_df))
print(RBL_df.shape)

print(RBL_df['NAICS Code Description'].unique()) #narrow the scope of the types of businesses we're searching for



RBL_df.loc[RBL_df['NAICS Code Description'] == "Food Services"]

# %%
import numpy as np
np.arange(1001,2000,50)
# Out:
# array([1001, 1051, 1101, 1151, 1201, 1251, 1301, 1351, 1401, 1451, 1501,
#        1551, 1601, 1651, 1701, 1751, 1801, 1851, 1901, 1951])
