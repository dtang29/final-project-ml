# %%
# Dependencies
import pandas as pd
import os

# %%
# Store filepath in a variable
file_one = os.path.join("../Raw", "Buyout_agreements.csv")

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
# Show 5 rows and the header 
file_one_df.head()
# Out:
#   Case Number Pre Buyout Disclosure Date Buyout Agreement Date Buyout Amount  \
# 0     B150588                    3/12/15                5/8/15   $32,000.00
# 1     B150590                    3/16/15               3/18/15    $6,000.00
# 2     B150597                    3/17/15              12/11/15   $54,000.00
# 3     B150601                    3/18/15                7/7/15   $30,000.00
# 4     B150606                    3/23/15               5/11/15   $21,000.00
#
#    Unknown Amount  Other Consideration  Number of Tenants  \
# 0           False                False                  4
# 1           False                False                  2
# 2           False                False                  2
# 3           False                False                  1
# 4           False                False                  7
#
#                    Block Address  ZIP Code  Supervisor District  \
# 0  1300 Block of Shotwell Street     94110                    9
# ...

# %%
file_one_df.columns
# Out:
# Index(['Case Number', 'Pre Buyout Disclosure Date', 'Buyout Agreement Date',
#        'Buyout Amount', 'Unknown Amount', 'Other Consideration',
#        'Number of Tenants', 'Block Address', 'ZIP Code', 'Supervisor District',
#        'Analysis Neighborhood', 'the_geom', 'SF Find Neighborhoods',
#        'Current Police Districts', 'Current Supervisor Districts',
#        'Analysis Neighborhoods', ':@computed_region_fyvs_ahh9',
#        ':@computed_region_p5aj_wyqh', ':@computed_region_rxqg_mtj9',
#        ':@computed_region_yftq_j783', ':@computed_region_bh8s_q3mv'],
#       dtype='object')

# %%
# Show mulitple specific columns--note the extra brackets
cleaned_buyouts = file_one_df[["Analysis Neighborhood","Block Address","ZIP Code","the_geom","Buyout Agreement Date","Buyout Amount", "Number of Tenants"]]
cleaned_buyouts.head()
# Out:
#   Analysis Neighborhood                  Block Address  ZIP Code  \
# 0        Bernal Heights  1300 Block of Shotwell Street     94110
# 1          Hayes Valley  600 Block of Broderick Street     94117
# 2            Noe Valley     100 Block of Valley Street     94131
# 3        Outer Richmond  3900 Block of Cabrillo Street     94121
# 4             Excelsior     200 Block of Munich Street     94112
#
#                                the_geom Buyout Agreement Date Buyout Amount  \
# 0  (37.747783872153, -122.414945488648)                5/8/15   $32,000.00
# 1  (37.776170112288, -122.439818697118)               3/18/15    $6,000.00
# 2  (37.744621476645, -122.425607962387)              12/11/15   $54,000.00
# 3   (37.773732167344, -122.50092850809)                7/7/15   $30,000.00
# 4  (37.721623443423, -122.426180850933)               5/11/15   $21,000.00
#
#    Number of Tenants
# 0                  4
# 1                  2
# 2                  2
# 3                  1
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
cleaned_buyouts.to_csv("Cleaned Datasets/Buyout_Agreements_cleaned.csv", index=False, header=True)
